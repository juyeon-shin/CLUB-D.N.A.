# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('full_data.csv')
data
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527245         1428218   2022-06-03 12:01:58       62         200
# 13527246         1428218   2022-06-03 12:01:49        2           7
# 13527247         1428218   2022-06-03 12:01:48       32         257
# 13527248         1428218   2022-06-03 12:01:48       33         110
# 13527249         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# ...

# %%
aaus = pd.read_csv('applicationid_append_user_spec_restored.csv')
aaus
# Out:
#          application_id user_id  \
# 0               1249046  118218
# 1                954900  553686
# 2                137274   59516
# 3               1570936  167320
# 4                967833   33400
# ...                 ...     ...
# 1394211         1864587  489900
# 1394212         1327066  151422
# 1394213         1319606  173524
# 1394214         1482466  766546
# 1394215          816537  no log
#
#                                                      event  \
# 0                                                       []
# 1        ['OpenApp', 'Login', 'StartLoanApply', 'ViewLo...
# 2                                        ['GetCreditInfo']
# 3        ['OpenApp', 'Login', 'StartLoanApply', 'ViewLo...
# 4        ['OpenApp', 'UseLoanManage', 'ViewLoanApplyInt...
# ...                                                    ...
# 1394211  ['Login', 'StartLoanApply', 'ViewLoanApplyIntr...
# 1394212  ['GetCreditInfo', 'GetCreditInfo', 'GetCreditI...
# ...

# %%
full = pd.read_csv('full_data.csv')
full
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527245         1428218   2022-06-03 12:01:58       62         200
# 13527246         1428218   2022-06-03 12:01:49        2           7
# 13527247         1428218   2022-06-03 12:01:48       32         257
# 13527248         1428218   2022-06-03 12:01:48       33         110
# 13527249         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied  user_id  birth_year  gender  ...  \
# ...
