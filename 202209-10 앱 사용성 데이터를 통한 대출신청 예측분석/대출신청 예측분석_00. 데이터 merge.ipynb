# %% [markdown]
# ### 대출신청 예측분석_00. 데이터 merge
# #### user_spec_fillna 전처리
#
# |col|전처리|
# |---|------|
# |user_id|앞뒤로 채우기|
# |company_enter_month|포맷변경 필요(연월)|
# |개인회생여부, 납입관련|0,-1|
# |기대출수관련|n,n->0,0 1,n-> 1,1median|
#
# ---
# + user_spec_fillna + loan_result

# %%
import pandas as pd
import numpy as np

# %%
user_spec_fillna = pd.read_csv('user_spec_fillna.csv')
loan_result = pd.read_csv('loan_result.csv')

# %%
user_spec_fillna
# Out:
#          application_id  user_id  birth_year  gender          insert_time  \
# 0               1031304        1      2000.0     1.0  2022-05-03 14:51:00
# 1               1767402        1      2000.0     1.0  2022-05-03 14:53:33
# 2               1096882        7      1985.0     1.0  2022-05-22 16:42:47
# 3                248576        9      1996.0     1.0  2022-05-21 23:41:09
# 4               1180616       11      1997.0     1.0  2022-03-24 10:58:22
# ...                 ...      ...         ...     ...                  ...
# 1394190         1889786   879694      1991.0     0.0  2022-03-31 20:17:31
# 1394191         1774704   879695      1996.0     1.0  2022-05-27 12:50:55
# 1394192         2149910   879696      1997.0     1.0  2022-03-14 05:23:30
# 1394193         1856758   879696      1997.0     1.0  2022-03-14 05:40:38
# 1394194         1543548   879697      1962.0     1.0  2022-05-10 20:40:52
#
#          credit_score  yearly_income    income_type  company_enter_month  \
# ...

# %%
loan_result
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527358         1428218   2022-06-03 12:01:58       62         200
# 13527359         1428218   2022-06-03 12:01:49        2           7
# 13527360         1428218   2022-06-03 12:01:48       32         257
# 13527361         1428218   2022-06-03 12:01:48       33         110
# 13527362         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied
# 0         42000000.0       13.6         NaN
# 1         24000000.0       17.9         NaN
# ...

# %%
loan_user = pd.merge(loan_result,user_spec_fillna,how='left', on='application_id')
loan_user
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                1748340   2022-06-07 13:05:41        7         191
# 1                1748340   2022-06-07 13:05:41       25         169
# 2                1748340   2022-06-07 13:05:41        2           7
# 3                1748340   2022-06-07 13:05:41        4         268
# 4                1748340   2022-06-07 13:05:41       11         118
# ...                  ...                   ...      ...         ...
# 13527358         1428218   2022-06-03 12:01:58       62         200
# 13527359         1428218   2022-06-03 12:01:49        2           7
# 13527360         1428218   2022-06-03 12:01:48       32         257
# 13527361         1428218   2022-06-03 12:01:48       33         110
# 13527362         1428218   2022-06-03 12:01:48        5         194
#
#           loan_limit  loan_rate  is_applied   user_id  birth_year  gender  \
# 0         42000000.0       13.6         NaN  430982.0      1996.0     1.0
# ...

# %%
loan_user.to_csv('loan_user_fill_merge.csv',index=False)
