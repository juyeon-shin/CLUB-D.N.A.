# %% [markdown]
# ### 220917_주연_대출신청 예측분석_0. merge_data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

import seaborn as sns

# %% [markdown]
# user_spec = pd.read_csv('user_spec.csv')
# loan_result = pd.read_csv('loan_result.csv')
# log_data = pd.read_csv('log_data.csv')

# %% [markdown]
# loan_user = pd.merge(loan_result,user_spec,how='left', on='application_id')
# loan_user
# loan_user.to_csv('loan_user_merge.csv',index=False)

# %%
loan_user = pd.read_csv('loan_user_merge.csv')

# %%
loan_user.isnull().sum()
# Out:
# application_id                                0
# loanapply_insert_time                         0
# bank_id                                       0
# product_id                                    0
# loan_limit                                 7495
# loan_rate                                  7495
# is_applied                              3257239
# user_id                                     113
# birth_year                               128209
# gender                                   128209
# insert_time                                 113
# credit_score                            1509389
# yearly_income                               119
# income_type                                 113
# company_enter_month                      400450
# employment_type                             113
# houseown_type                               113
# desired_amount                              113
# purpose                                     113
# personal_rehabilitation_yn              5888814
# ...

# %%
loan_user_sort = loan_user.sort_values('loanapply_insert_time')
loan_user_sort
# Out:
#          application_id loanapply_insert_time  bank_id  product_id  \
# 754902           566528   2022-03-01 00:11:36       13         123
# 1116695          180433   2022-03-01 00:12:05       13         262
# 1116692          180433   2022-03-01 00:12:05       19         231
# 2660438         1657888   2022-03-01 00:12:06       19         231
# 2660440         1657888   2022-03-01 00:12:06       24         263
# ...                 ...                   ...      ...         ...
# 9024947          634459   2022-06-30 23:54:48       10          65
# 9024951          634459   2022-06-30 23:54:48       10         149
# 9024953          634459   2022-06-30 23:54:48       19         231
# 8983167         1288711   2022-06-30 23:54:52       35         267
# 8983165         1288711   2022-06-30 23:55:00       27         176
#
#          loan_limit  loan_rate  is_applied   user_id  birth_year  gender  ...  \
# 754902   20000000.0       19.1         0.0  681184.0      1974.0     1.0  ...
# ...

# %%
train_loan_user = loan_user_sort[loan_user_sort['loanapply_insert_time']<'2022-06-01 00:00:00']
test_loan_user = loan_user_sort[loan_user_sort['loanapply_insert_time']>='2022-06-01 00:00:00']

# %%
train_loan_user = train_loan_user.reset_index(drop=True)
train_loan_user
# Out:
#           application_id loanapply_insert_time  bank_id  product_id  \
# 0                 566528   2022-03-01 00:11:36       13         123
# 1                 180433   2022-03-01 00:12:05       13         262
# 2                 180433   2022-03-01 00:12:05       19         231
# 3                1657888   2022-03-01 00:12:06       19         231
# 4                1657888   2022-03-01 00:12:06       24         263
# ...                  ...                   ...      ...         ...
# 10270119          455157   2022-05-31 23:54:28       35         168
# 10270120          455157   2022-05-31 23:54:28       55         159
# 10270121          455157   2022-05-31 23:54:29       22         221
# 10270122          455157   2022-05-31 23:54:37       38          16
# 10270123          831190   2022-05-31 23:54:38       52         187
#
#           loan_limit  loan_rate  is_applied   user_id  birth_year  gender  \
# 0         20000000.0       19.1         0.0  681184.0      1974.0     1.0
# ...

# %%
test_loan_user = test_loan_user.reset_index(drop=True)
test_loan_user
# Out:
#          application_id loanapply_insert_time  bank_id  product_id  \
# 0                506292   2022-06-01 00:12:24       27         148
# 1                506292   2022-06-01 00:12:24       59         251
# 2               1255231   2022-06-01 00:12:24       29         265
# 3                506292   2022-06-01 00:12:24       19         231
# 4                506292   2022-06-01 00:12:25       56           5
# ...                 ...                   ...      ...         ...
# 3257234          634459   2022-06-30 23:54:48       10          65
# 3257235          634459   2022-06-30 23:54:48       10         149
# 3257236          634459   2022-06-30 23:54:48       19         231
# 3257237         1288711   2022-06-30 23:54:52       35         267
# 3257238         1288711   2022-06-30 23:55:00       27         176
#
#          loan_limit  loan_rate  is_applied   user_id  birth_year  gender  ...  \
# 0        13000000.0        7.2         NaN  669202.0      1981.0     1.0  ...
# ...

# %%
train_loan_user.to_csv('train_loan_user.csv',index=False)
test_loan_user.to_csv('test_loan_user.csv',index=False)
