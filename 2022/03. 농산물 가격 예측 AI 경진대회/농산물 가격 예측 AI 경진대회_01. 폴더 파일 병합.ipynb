# %%
import pandas as pd
import numpy as np
import glob
import multiprocessing
import pickle
import process

# %%
train_list= glob.glob('C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL/*.csv')
train_list
# Out:
# ['C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201601.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201602.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201603.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201604.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201605.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201606.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201607.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201608.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201609.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201610.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201611.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201612.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201701.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201702.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201703.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201704.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201705.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201706.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201707.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201708.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201709.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201710.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201711.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201712.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201801.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201802.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201803.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201804.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201805.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201806.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201807.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201808.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201809.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201810.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201811.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201812.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201901.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201902.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201903.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201904.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201905.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201906.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201907.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201908.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201909.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201910.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201911.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_201912.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202001.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202002.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202003.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202004.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202005.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202006.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202007.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202008.csv',
#  'C:/Users/juyeo/Desktop/03. 농산물 가격예측 AI 경진대회/public_data/train_AT_TSALET_ALL\\AT_TSALET_ALL_202009.csv']

# %%
train_at = pd.DataFrame()

for train in train_list:
    current_data = pd.read_csv(train)
    train_at = pd.concat([train_at,current_data])
    print(current_data)
# Out:
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 1        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 2        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 3        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 4        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2700791  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700792  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700793  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700794  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
# 2700795  20160130   서울강서도매   강서청과      배      신고     kg      .       .     .
#
#           SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0        제주도 제주시  10.0   62  14400.0    620.0   892800
# 1        제주도 제주시  10.0   29  14700.0    290.0   426300
# 2        제주도 제주시  10.0   17  12800.0    170.0   217600
# 3        제주도 제주시  10.0   16   8800.0    160.0   140800
# 4        제주 남제주군  10.0   25   7300.0    250.0   182500
# ...          ...   ...  ...      ...      ...      ...
# 2700791   경기 평택시   7.5   60  30000.0    450.0  1800000
# 2700792   경기 평택시   7.5   60  30000.0    450.0  1800000
# 2700793   경기 평택시   7.5   36  30000.0    270.0  1080000
# 2700794   경기 평택시   7.5   35  23000.0    262.5   805000
# 2700795   경기 평택시   7.5    4  14000.0     30.0    56000
#
# [2700796 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20160210   전주도매시장   전주청과     만감     한라봉     kg     상자       .     특
# 1        20160210   전주도매시장   전주청과     만감     한라봉     kg     상자       .     특
# 2        20160210   전주도매시장   전주청과     만감     한라봉     kg     상자       .     특
# 3        20160210   전주도매시장   전주청과     만감     한라봉     kg     상자       .     특
# 4        20160210   전주도매시장   전주청과     만감     한라봉     kg     상자       .     특
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2432156  20160229   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
# 2432157  20160229   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
# 2432158  20160229   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
# 2432159  20160229   서울강서도매   강서청과    풋고추      청양     kg     상자       .     .
# 2432160  20160229   서울강서도매   강서청과    풋고추      청양     kg     상자       .     .
#
#          SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0           NaN   5.0   13  23000     65.0   299000
# 1           NaN   5.0    9  23000     45.0   207000
# 2           NaN   5.0   12  22000     60.0   264000
# 3           NaN   5.0   18  20000     90.0   360000
# 4           NaN   5.0   14  19000     70.0   266000
# ...         ...   ...  ...    ...      ...      ...
# 2432156  강원 평창군  12.0 -300   5200  -3600.0 -1560000
# 2432157  강원 평창군  12.0  800   8700   9600.0  6960000
# 2432158  강원 평창군  12.0  200   4900   2400.0   980000
# 2432159  경남 진주시   7.0   -1  59500     -7.0   -59500
# 2432160  경남 진주시   7.0    1  51000      7.0    51000
#
# [2432161 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20160310   부산엄궁도매   부산청과    토마토  토마토(일반)     kg     상자       .    보통
# 1        20160310   부산엄궁도매   부산청과    토마토  토마토(일반)     kg     상자       .    보통
# 2        20160310   부산엄궁도매   부산청과  방울토마토     대추방울     kg     상자       .    보통
# 3        20160310   부산엄궁도매   부산청과  방울토마토     대추방울     kg     상자       .    보통
# 4        20160310   부산엄궁도매   부산청과  방울토마토     대추방울     kg     상자       .    보통
# ...           ...      ...    ...    ...      ...    ...    ...     ...   ...
# 3178985  20160331   서울강서도매   강서청과     마늘      깐마늘     kg    파렛트       .     .
# 3178986  20160331   서울강서도매   강서청과     마늘  깐마늘(수입)     kg    파렛트       .     .
# 3178987  20160331   서울강서도매   강서청과     마늘  깐마늘(수입)     kg    파렛트       .     .
# 3178988  20160331   서울강서도매   강서청과     마늘  깐마늘(수입)     kg    파렛트       .     .
# 3178989  20160331   서울강서도매   강서청과     마늘  깐마늘(수입)     kg    파렛트       .     .
#
#            SAN_NM  DANQ  QTY    COST  TOT_QTY  TOT_AMT
# 0           부산 중구   5.0    4   26600     20.0   106400
# 1           부산 중구   5.0    3   27500     15.0    82500
# 2        경상남도 김해시   2.0    2   14300      4.0    28600
# 3        경상남도 김해시   2.0   31   15200     62.0   471200
# 4        경상남도 김해시   2.0   20   12400     40.0   248000
# ...           ...   ...  ...     ...      ...      ...
# 3178985    전남 무안군  20.0    2  145000     40.0   290000
# 3178986    전남 무안군  20.0    1  113700     20.0   113700
# 3178987    전남 무안군  20.0    1  113700     20.0   113700
# 3178988    전남 무안군  20.0    5  113700    100.0   568500
# 3178989    전남 무안군  20.0    1  108500     20.0   108500
#
# [3178990 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20160409   인천삼산도매   부평농산     상추      청상추     kg     상자       .     특
# 1        20160409   인천삼산도매   부평농산    머위대      머위잎     kg     상자       .     특
# 2        20160409   인천삼산도매   부평농산    머위대      머위잎     kg     상자       .     특
# 3        20160409   인천삼산도매   부평농산    취나물  취나물(일반)     kg     상자       .     특
# 4        20160409   인천삼산도매   부평농산    고사리    기타고사리     kg     상자       .     특
# ...           ...      ...    ...    ...      ...    ...    ...     ...   ...
# 3397850  20160430   서울강서도매   강서청과     우엉       우엉     kg     상자       .     .
# 3397851  20160430   서울강서도매   강서청과     당근       당근     kg     상자       .     .
# 3397852  20160430   서울강서도매   강서청과    토마토    기타토마토     kg      .       .     .
# 3397853  20160430   서울강서도매   강서청과    토마토    기타토마토     kg      .       .     .
# 3397854  20160430   서울강서도매   강서청과    토마토    기타토마토     kg      .       .     .
#
#          SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0        충남 논산시   4.0   30   4000    120.0   120000
# 1        충남 논산시   4.0    6  11000     24.0    66000
# 2        충남 논산시   4.0   15  12500     60.0   187500
# 3        전남 고흥군   4.0   30   7500    120.0   225000
# 4        전남 고흥군   4.0    8  16000     32.0   128000
# ...         ...   ...  ...    ...      ...      ...
# 3397850  서울 강서구   8.0  300  10000   2400.0  3000000
# 3397851  서울 강서구  10.0  160  10000   1600.0  1600000
# 3397852  부산 강서구   5.0    6  26000     30.0   156000
# 3397853  부산 강서구   5.0    4  22000     20.0    88000
# 3397854  부산 강서구   5.0    8  12000     40.0    96000
#
# [3397855 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM        PUM_NM   KIND_NM DAN_NM POJ_NM  \
# 0        20160510   인천삼산도매   부평농산  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
# 1        20160510   인천삼산도매   부평농산         얼갈이배추     얼갈이배추     kg   비닐봉지
# 2        20160510   인천삼산도매   부평농산            열무    열무(일반)     kg   비닐봉지
# 3        20160510   인천삼산도매   부평농산            아욱    아욱(일반)     kg      단
# 4        20160510   인천삼산도매   부평농산            열무    열무(일반)     kg     상자
# ...           ...      ...    ...           ...       ...    ...    ...
# 3581546  20160531   서울강서도매   강서청과           바나나       바나나     kg      .
# 3581547  20160531   서울강서도매   강서청과           바나나       바나나     kg      .
# 3581548  20160531   서울강서도매   강서청과           바나나       바나나     kg      .
# 3581549  20160531   서울강서도매   강서청과           바나나       바나나     kg      .
# 3581550  20160531   서울강서도매   강서청과           바나나       바나나     kg      .
#
#         SIZE_NM LV_NM   SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0             .     특  제주 북제주군   8.0   13  10000    104.0   130000
# 1             .     특    인천 서구   4.0   18   1700     72.0    30600
# 2             .     특    인천 서구   4.0    1   2000      4.0     2000
# 3             .     특   경기 김포시   0.5  100   1330     50.0   133000
# 4             .     특   인천 계양구   4.0   30   2500    120.0    75000
# ...         ...   ...      ...   ...  ...    ...      ...      ...
# 3581546       .     .   인천 남동구  13.0   10  22000    130.0   220000
# 3581547       .     .   인천 남동구  13.0   20  22000    260.0   440000
# 3581548       .     .   인천 남동구  13.0   10  22000    130.0   220000
# 3581549       .     .   인천 남동구  13.0   10  22000    130.0   220000
# 3581550       .     .   인천 남동구  13.0   53  15000    689.0   795000
#
# [3581551 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM        PUM_NM   KIND_NM DAN_NM POJ_NM  \
# 0        20160610   구리도매시장  인터넷청과            참외      금싸라기     kg     상자
# 1        20160610   구리도매시장  인터넷청과            참외      금싸라기     kg     상자
# 2        20160610   구리도매시장  인터넷청과            참외      금싸라기     kg     상자
# 3        20160610   구리도매시장  인터넷청과            참외      금싸라기     kg     상자
# 4        20160610   구리도매시장  인터넷청과            참외      금싸라기     kg     상자
# ...           ...      ...    ...           ...       ...    ...    ...
# 3950747  20160630   서울강서도매   강서청과            자두      기타자두     kg      .
# 3950748  20160630   서울강서도매   강서청과            자두      기타자두     kg      .
# 3950749  20160630   서울강서도매   강서청과            자두      기타자두     kg      .
# 3950750  20160630   서울강서도매   강서청과  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
# 3950751  20160630   서울강서도매   강서청과  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
#
#           SIZE_NM LV_NM    SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0        1개(내_뿌리)     특  경상북도 성주군  10.0    1  20000.0     10.0    20000
# 1        1개(내_뿌리)     특  경상북도 성주군  10.0    2  22000.0     20.0    44000
# 2        1개(내_뿌리)     특  경상북도 성주군  10.0   11  26000.0    110.0   286000
# 3        1개(내_뿌리)     특  경상북도 성주군  10.0   25  30000.0    250.0   750000
# 4        1개(내_뿌리)     특  경상북도 성주군  10.0   20  27000.0    200.0   540000
# ...           ...   ...       ...   ...  ...      ...      ...      ...
# 3950747         .     .    경북 의성군   5.0   11  11500.0     55.0   126500
# 3950748         .     .    경북 의성군   5.0    2   4000.0     10.0     8000
# 3950749         .     .    경북 의성군   5.0   15   6500.0     75.0    97500
# 3950750         .     .    충북 충주시   8.0  -15  13000.0   -120.0  -195000
# 3950751         .     .    충북 충주시   8.0   12  13000.0     96.0   156000
#
# [3950752 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20160709   구리도매시장  인터넷청과    복숭아   기타복숭아     kg     상자  1개(내_뿌리)
# 1        20160709   구리도매시장  인터넷청과    복숭아   기타복숭아     kg     상자  1개(내_뿌리)
# 2        20160709   구리도매시장  인터넷청과    복숭아   기타복숭아     kg     상자  1개(내_뿌리)
# 3        20160709   구리도매시장  인터넷청과    복숭아   기타복숭아     kg     상자  1개(내_뿌리)
# 4        20160709   구리도매시장  인터넷청과    복숭아   기타복숭아     kg     상자  1개(내_뿌리)
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 4029405  20160730   서울가락도매   대아청과     배추     쌈배추     kg     상자       16개
# 4029406  20160730   서울가락도매   대아청과     배추    여름배추     kg    그물망        3개
# 4029407  20160730   서울가락도매   대아청과     배추    여름배추     kg    그물망        3개
# 4029408  20160730   서울가락도매   대아청과     배추    여름배추     kg    그물망        3개
# 4029409  20160730   서울가락도매   대아청과     배추    여름배추     kg    그물망        3개
#
#         LV_NM    SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           특  경상북도 상주시   4.5    1  10000.0      4.5    10000
# 1           특  경상북도 상주시   4.5    3   7000.0     13.5    21000
# 2           특  경상북도 상주시   4.5    2  13000.0      9.0    26000
# 3           특  경상북도 상주시   4.5    7   8000.0     31.5    56000
# 4           특  경상북도 상주시   4.5    7   7000.0     31.5    49000
# ...       ...       ...   ...  ...      ...      ...      ...
# 4029405     상   강원도 평창군   8.0   20   8000.0    160.0   160000
# 4029406     특   강원도 정선군  10.0 -759  -3700.0  -7590.0 -2808300
# 4029407     상   강원도 정선군  10.0 -200  -2200.0  -2000.0  -440000
# 4029408     특   강원도 정선군  10.0  718   3700.0   7180.0  2656600
# 4029409     상   강원도 정선군  10.0  200   2200.0   2000.0   440000
#
# [4029410 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20160810   부산엄궁도매   부산청과    복숭아   천중도백도     kg     상자       .    보통
# 1        20160810   부산엄궁도매   부산청과    복숭아   천중도백도     kg     상자       .    보통
# 2        20160810   부산엄궁도매   부산청과    복숭아   천중도백도     kg     상자       .    보통
# 3        20160810   부산엄궁도매   부산청과    복숭아   천중도백도     kg     상자       .    보통
# 4        20160810   부산엄궁도매   부산청과    복숭아    환타지아     kg     상자       .    보통
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 4034213  20160831   서울강서도매   강서청과      배      원황     kg      .       .     .
# 4034214  20160831   서울강서도매   강서청과      배      원황     kg      .       .     .
# 4034215  20160831   서울강서도매   강서청과      배      원황     kg      .       .     .
# 4034216  20160831   서울강서도매   강서청과      배      원황     kg      .       .     .
# 4034217  20160831   서울강서도매   강서청과      배      원황     kg      .       .     .
#
#            SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0        경상북도 청도군   4.5   12  10300.0     54.0   123600
# 1        경상북도 청도군   4.5   12   8500.0     54.0   102000
# 2        경상북도 청도군   4.5    6   6600.0     27.0    39600
# 3        경상북도 청도군  10.0    1   5500.0     10.0     5500
# 4        경상북도 청도군  10.0    3  25200.0     30.0    75600
# ...           ...   ...  ...      ...      ...      ...
# 4034213    경기 평택시  15.0    1  18000.0     15.0    18000
# 4034214    경기 평택시  15.0    7  17000.0    105.0   119000
# 4034215    경기 평택시  15.0   19  13000.0    285.0   247000
# 4034216    경기 평택시  15.0   10  11000.0    150.0   110000
# 4034217    경기 평택시  15.0   14   8500.0    210.0   119000
#
# [4034218 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20160910   부산엄궁도매   부산청과     사과      홍로     kg     상자         .
# 1        20160910   부산엄궁도매   부산청과     사과      홍로     kg     상자         .
# 2        20160910   부산엄궁도매   부산청과     사과      홍로     kg     상자         .
# 3        20160910   부산엄궁도매   부산청과     사과      홍로     kg     상자         .
# 4        20160910   부산엄궁도매   부산청과     사과      홍로     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 3427070  20160930   서울강서도매   강서청과     배추    기타배추     kg      접         .
# 3427071  20160930   서울강서도매   강서청과     배추    기타배추     kg      접         .
# 3427072  20160930   서울강서도매   강서청과     배추    기타배추     kg      접         .
# 3427073  20160930   서울강서도매   강서청과     쑥갓  쑥갓(일반)     kg     상자  1개(내_뿌리)
# 3427074  20160930   서울강서도매   강서청과     쑥갓  쑥갓(일반)     kg     상자  1개(내_뿌리)
#
#         LV_NM       SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0          보통     경상남도 거창군   5.0   68   8800.0    340.0   598400
# 1           상     경상남도 거창군   5.0   25  10000.0    125.0   250000
# 2          보통     경상남도 거창군   5.0   17   9000.0     85.0   153000
# 3          보통     경상남도 거창군   5.0   46   7000.0    230.0   322000
# 4          보통     경상남도 거창군   5.0   43   5000.0    215.0   215000
# ...       ...          ...   ...  ...      ...      ...      ...
# 3427070     .       강원 정선군  12.0  620  14000.0   7440.0  8680000
# 3427071     .       강원 정선군  12.0  120   7000.0   1440.0   840000
# 3427072     .       강원 정선군  12.0  198   8400.0   2376.0  1663200
# 3427073     .  경기 고양시 일산서구   4.0  -30   2300.0   -120.0   -69000
# 3427074     .  경기 고양시 일산서구   4.0  -30   2400.0   -120.0   -72000
#
# [3427075 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20161010   인천구월도매   덕풍청과    양배추  양배추(일반)     kg    그물망       .     상
# 1        20161010   인천구월도매   덕풍청과    양배추  양배추(일반)     kg    그물망       .     상
# 2        20161010   인천구월도매   덕풍청과    양배추  양배추(일반)     kg    그물망       .     특
# 3        20161010   인천구월도매   덕풍청과    양배추  양배추(일반)     kg    그물망       .     특
# 4        20161010   인천구월도매   덕풍청과    양배추  양배추(일반)     kg    그물망       .     특
# ...           ...      ...    ...    ...      ...    ...    ...     ...   ...
# 3435170  20161031   서울강서도매   강서청과     기타  과채류(기타)     kg     상자       .     .
# 3435171  20161031   서울강서도매   강서청과     기타  과채류(기타)     kg     상자       .     .
# 3435172  20161031   서울강서도매   강서청과     기타  과채류(기타)     kg     상자       .     .
# 3435173  20161031   서울강서도매   강서청과     기타  과채류(기타)     kg     상자       .     .
# 3435174  20161031   서울강서도매   강서청과     기타  과채류(기타)     kg     상자       .     .
#
#           SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0        강원도 정선군   8.0   50   6500.0    400.0   325000
# 1        강원도 정선군   8.0   15   6500.0    120.0    97500
# 2        강원도 정선군   8.0   15   6000.0    120.0    90000
# 3        강원도 정선군   8.0   14   6000.0    112.0    84000
# 4        강원도 정선군   8.0   15   6000.0    120.0    90000
# ...          ...   ...  ...      ...      ...      ...
# 3435170   경기 포천시  20.0   -2  17000.0    -40.0   -34000
# 3435171   경기 포천시  20.0   -2  16000.0    -40.0   -32000
# 3435172   경기 포천시  20.0    1  17000.0     20.0    17000
# 3435173   경기 포천시  20.0    2  17000.0     40.0    34000
# 3435174   경기 포천시  20.0    2  16000.0     40.0    32000
#
# [3435175 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM    POJ_NM SIZE_NM  \
# 0        20161110   인천구월도매   덕풍청과     사과     미안마     kg        상자       .
# 1        20161110   인천구월도매   덕풍청과     사과     미안마     kg        상자       .
# 2        20161110   인천구월도매   덕풍청과     사과     미안마     kg        상자       .
# 3        20161110   인천구월도매   덕풍청과     사과     미안마     kg        상자       .
# 4        20161110   인천구월도매   덕풍청과     사과      후지     kg        상자       .
# ...           ...      ...    ...    ...     ...    ...       ...     ...
# 2948661  20161130   서울강서도매   강서청과    풋고추      청양     kg        상자      2개
# 2948662  20161130   서울강서도매   강서청과    풋고추      청양     kg        상자      3개
# 2948663  20161130   서울강서도매   강서청과    풋고추      청양     kg        상자       .
# 2948664  20161130   서울강서도매   강서청과      무     다발무     kg  접시용기 트래이       .
# 2948665  20161130   서울강서도매   강서청과      무     다발무     kg  접시용기 트래이       .
#
#         LV_NM    SAN_NM    DANQ  QTY       COST  TOT_QTY  TOT_AMT
# 0           특  충청북도 충주시    10.0   26    15000.0    260.0   390000
# 1           특  충청북도 충주시    10.0   42    14000.0    420.0   588000
# 2           특  충청북도 충주시    10.0   12    11000.0    120.0   132000
# 3           특  충청북도 충주시    10.0    7     7000.0     70.0    49000
# 4           특  충청북도 충주시    10.0   49    22000.0    490.0  1078000
# ...       ...       ...     ...  ...        ...      ...      ...
# 2948661     .    전남 담양군    10.0    3    32000.0     30.0    96000
# 2948662     .    전남 담양군    10.0    1    28000.0     10.0    28000
# 2948663     .    전남 담양군    10.0    1    31000.0     10.0    31000
# 2948664     .   경기 남양주시  8000.0   -1  6300000.0  -8000.0 -6300000
# 2948665     .   경기 남양주시  8000.0    1  6000000.0   8000.0  6000000
#
# [2948666 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20161210   인천구월도매   덕풍청과     감귤     조생귤     kg     상자       .     특
# 1        20161210   인천구월도매   덕풍청과     감귤     조생귤     kg     상자       .     특
# 2        20161210   인천구월도매   덕풍청과     감귤     조생귤     kg     상자       .     특
# 3        20161210   인천구월도매   덕풍청과     감귤     조생귤     kg     상자       .     특
# 4        20161210   인천구월도매   덕풍청과     감귤     조생귤     kg     상자       .     특
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2874705  20161231   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2874706  20161231   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2874707  20161231   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2874708  20161231   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2874709  20161231   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
#
#            SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0        제주도 서귀포시  10.0   19  10000    190.0   190000
# 1        제주도 서귀포시  10.0   19  13000    190.0   247000
# 2        제주도 서귀포시  10.0   19  13000    190.0   247000
# 3        제주도 서귀포시  10.0   19  13000    190.0   247000
# 4        제주도 서귀포시  10.0   29  14500    290.0   420500
# ...           ...   ...  ...    ...      ...      ...
# 2874705    서울 송파구   0.0   12  14000    -65.0   168000
# 2874706    서울 송파구   0.0  -24  14000     35.0  -336000
# 2874707    서울 송파구   0.0  -12  14000    156.0  -168000
# 2874708    서울 송파구   0.0  -12  14000     65.0  -168000
# 2874709    서울 송파구   0.0  -12  14000    156.0  -168000
#
# [2874710 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20170110   안산도매시장  안산농산물   팽이버섯     팽이1호     kg     상자       .     특
# 1        20170110   안산도매시장  안산농산물   팽이버섯     팽이1호     kg     상자       .     특
# 2        20170110   안산도매시장  안산농산물    만가닥  만가닥(일반)     kg     상자       .     특
# 3        20170110   안산도매시장  안산농산물    만가닥  만가닥(일반)     kg     상자       .     특
# 4        20170110   안산도매시장  안산농산물    만가닥  만가닥(일반)     kg     상자       .     특
# ...           ...      ...    ...    ...      ...    ...    ...     ...   ...
# 2758418  20170130   서울강서도매   서부청과     딸기       장희     kg      .       .    보통
# 2758419  20170130   서울강서도매   서부청과     딸기       장희     kg      .       .     상
# 2758420  20170130   서울강서도매   서부청과     딸기       장희     kg      .       .     특
# 2758421  20170130   서울강서도매   서부청과     딸기       장희     kg      .       .     상
# 2758422  20170130   서울강서도매   서부청과     딸기       장희     kg      .       .    보통
#
#            SAN_NM  DANQ  QTY    COST  TOT_QTY  TOT_AMT
# 0          전남 나주시   5.0   10  8500.0     50.0    85000
# 1          전남 나주시   5.0   40  8500.0    200.0   340000
# 2          전남 함평군   2.0    3  5500.0      6.0    16500
# 3          전남 함평군   2.0    3  5500.0      6.0    16500
# 4          전남 함평군   2.0    7  5500.0     14.0    38500
# ...           ...   ...  ...     ...      ...      ...
# 2758418  경상남도 거창군   1.0   40  6000.0     40.0   240000
# 2758419  경상남도 거창군   1.0   10  3000.0     10.0    30000
# 2758420  경상남도 거창군   1.0   10  7000.0     10.0    70000
# 2758421  경상남도 거창군   1.0   10  4500.0     10.0    45000
# 2758422  경상남도 거창군   1.0   40  3500.0     40.0   140000
#
# [2758423 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM    POJ_NM   SIZE_NM  \
# 0        20170210   인천구월도매   덕풍청과     딸기      설향     kg        상자         .
# 1        20170210   인천구월도매   덕풍청과     딸기      설향     kg        상자         .
# 2        20170210   인천구월도매   덕풍청과     딸기      설향     kg        상자         .
# 3        20170210   인천구월도매   덕풍청과     딸기      설향     kg        상자         .
# 4        20170210   인천구월도매   덕풍청과     딸기      설향     kg  접시용기 트래이         .
# ...           ...      ...    ...    ...     ...    ...       ...       ...
# 2628851  20170228   서울강서도매   강서청과     대파  대파(일반)     kg       PE대  1개(내_뿌리)
# 2628852  20170228   서울강서도매   강서청과     대파  대파(일반)     kg       PE대  1개(내_뿌리)
# 2628853  20170228   서울강서도매   강서청과     대파  대파(일반)     kg       PE대  1개(내_뿌리)
# 2628854  20170228   서울강서도매   강서청과     대파  대파(일반)     kg       PE대  1개(내_뿌리)
# 2628855  20170228   서울강서도매   강서청과     대파  대파(일반)     kg       PE대  1개(내_뿌리)
#
#         LV_NM       SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           특     경상남도 하동군   2.0   29  13000.0     58.0   377000
# 1           특     경상남도 하동군   2.0   26   9500.0     52.0   247000
# 2           특     경상남도 하동군   2.0   30   9500.0     60.0   285000
# 3           상     경상남도 하동군   2.0    8   7000.0     16.0    56000
# 4           특     경상남도 하동군   1.0   44   6500.0     44.0   286000
# ...       ...          ...   ...  ...      ...      ...      ...
# 2628851     .  경기 고양시 일산동구   1.0 -450   1700.0   -450.0  -765000
# 2628852     .   경기 고양시 덕양구   1.0  350   1700.0    350.0   595000
# 2628853     .   경기 고양시 덕양구   1.0  440   1700.0    440.0   748000
# 2628854     .   경기 고양시 덕양구   1.0  450   1700.0    450.0   765000
# 2628855     .   경기 고양시 덕양구   1.0  450   1700.0    450.0   765000
#
# [2628856 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20170310   수원도매시장   수원청과     딸기      설향     kg      .       .     .
# 1        20170310   수원도매시장   수원청과     딸기      설향     kg      .       .     .
# 2        20170310   수원도매시장   수원청과     딸기      설향     kg      .       .     .
# 3        20170310   수원도매시장   수원청과     딸기      설향     kg      .       .     .
# 4        20170310   수원도매시장   수원청과     딸기      설향     kg      .       .     .
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 3393632  20170331   서울강서도매   강서청과     포도      포도     kg      .       .     .
# 3393633  20170331   서울강서도매   강서청과     포도      포도     kg      .       .     .
# 3393634  20170331   서울강서도매   강서청과     포도      포도     kg      .       .     .
# 3393635  20170331   서울강서도매   강서청과     포도      포도     kg      .       .     .
# 3393636  20170331   서울강서도매   강서청과     포도      포도     kg      .       .     .
#
#          SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0        충남 논산시   2.0   39  12500.0     78.0   487500
# 1        충남 논산시   2.0    1   6000.0      2.0     6000
# 2        충남 논산시   2.0   55  11500.0    110.0   632500
# 3        충남 논산시   2.0   26   7000.0     52.0   182000
# 4        충남 논산시   2.0    9   5200.0     18.0    46800
# ...         ...   ...  ...      ...      ...      ...
# 3393632  서울 송파구   9.0   10  26000.0     90.0   260000
# 3393633  서울 송파구   9.0   10  26000.0     90.0   260000
# 3393634  서울 송파구   9.0   10  26000.0     90.0   260000
# 3393635  서울 송파구   9.0   10  26000.0     90.0   260000
# 3393636  서울 송파구   9.0   10  26000.0     90.0   260000
#
# [3393637 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM   PUM_NM  KIND_NM DAN_NM POJ_NM SIZE_NM  \
# 0        20170410   수원도매시장   수원청과       참외       오복     kg      .       .
# 1        20170410   수원도매시장   수원청과       참외       오복     kg      .       .
# 2        20170410   수원도매시장   수원청과       참외       오복     kg      .       .
# 3        20170410   수원도매시장   수원청과       참외       오복     kg      .       .
# 4        20170410   수원도매시장   수원청과       참외       오복     kg      .       .
# ...           ...      ...    ...      ...      ...    ...    ...     ...
# 3439197  20170429   서울강서도매   강서청과  참다래(키위)  참다래(키위)     kg      .       .
# 3439198  20170429   서울강서도매   강서청과  참다래(키위)  참다래(키위)     kg      .       .
# 3439199  20170429   서울강서도매   강서청과  참다래(키위)  참다래(키위)     kg      .       .
# 3439200  20170429   서울강서도매   강서청과  참다래(키위)  참다래(키위)     kg      .       .
# 3439201  20170429   서울강서도매   강서청과  참다래(키위)  참다래(키위)     kg      .       .
#
#         LV_NM  SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0           .  경북 김천시  10.0    1  28000     10.0    28000
# 1           .  경북 김천시  10.0    1  27000     10.0    27000
# 2           .  경북 김천시  10.0    1  24000     10.0    24000
# 3           .  경북 김천시  10.0    6  21000     60.0   126000
# 4           .  경북 성주군   5.0    1  21000      5.0    21000
# ...       ...     ...   ...  ...    ...      ...      ...
# 3439197     .  서울 송파구  10.0   30  18000    300.0   540000
# 3439198     .  서울 송파구  10.0   20  18000    200.0   360000
# 3439199     .  서울 송파구  10.0   10  18000    100.0   180000
# 3439200     .  서울 송파구  10.0   10  18000    100.0   180000
# 3439201     .  서울 송파구  10.0   12  18000    120.0   216000
#
# [3439202 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20170510   수원도매시장   수원청과     딸기      설향     kg  P-BOX       .     .
# 1        20170510   수원도매시장   수원청과     딸기      설향     kg  P-BOX       .     .
# 2        20170510   수원도매시장   수원청과     딸기      설향     kg  P-BOX       .     .
# 3        20170510   수원도매시장   수원청과     딸기      설향     kg  P-BOX       .     .
# 4        20170510   수원도매시장   수원청과     딸기      설향     kg  P-BOX       .     .
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 3607602  20170531   서울강서도매   강서청과     양파    기타양파     kg      접      3개     .
# 3607603  20170531   서울강서도매   강서청과     양파    기타양파     kg      접       .     .
# 3607604  20170531   서울강서도매   강서청과     양파    기타양파     kg      접       .     .
# 3607605  20170531   서울강서도매   강서청과     양파    기타양파     kg      접       .     .
# 3607606  20170531   서울강서도매   강서청과     양파    기타양파     kg      접      3개     .
#
#          SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0        충남 논산시   1.0   84   5200     84.0   436800
# 1        충남 논산시   1.0   43   3600     43.0   154800
# 2        충남 논산시   1.0   21   3000     21.0    63000
# 3        충남 논산시   1.0   20   3000     20.0    60000
# 4        충남 논산시   1.0   17   2300     17.0    39100
# ...         ...   ...  ...    ...      ...      ...
# 3607602  전남 무안군  12.0  -69   7600   -828.0  -524400
# 3607603  전남 무안군  15.0  162  14800   2430.0  2397600
# 3607604  전남 무안군  12.0  140  10600   1680.0  1484000
# 3607605  전남 무안군  12.0   91   9600   1092.0   873600
# 3607606  전남 무안군  12.0   64   7600    768.0   486400
#
# [3607607 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20170610   인천구월도매  인천농산물    바나나   기타바나나     kg     상자         .
# 1        20170610   인천구월도매  인천농산물    바나나   기타바나나     kg     상자         .
# 2        20170610   인천구월도매  인천농산물    바나나   기타바나나     kg     상자         .
# 3        20170610   인천구월도매  인천농산물    바나나   기타바나나     kg     상자         .
# 4        20170610   인천구월도매  인천농산물    바나나   기타바나나     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 4031127  20170630   서울강서도매   강서청과  방울토마토    대추방울     kg      .  1개(내_뿌리)
# 4031128  20170630   서울강서도매   강서청과     배추    기타배추     kg      접         .
# 4031129  20170630   서울강서도매   강서청과     배추    기타배추     kg      접         .
# 4031130  20170630   서울강서도매   강서청과     배추    기타배추     kg      접         .
# 4031131  20170630   서울강서도매   강서청과     배추    기타배추     kg      접         .
#
#         LV_NM  SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           상   에쿠아도르  13.0    5  27000.0     65.0   135000
# 1           상   에쿠아도르  13.0   10  27000.0    130.0   270000
# 2           상   에쿠아도르  13.0    1  27000.0     13.0    27000
# 3           상   에쿠아도르  13.0    8  27000.0    104.0   216000
# 4           상     필리핀  13.0    5  25000.0     65.0   125000
# ...       ...     ...   ...  ...      ...      ...      ...
# 4031127     .  경기 평택시   3.0   25   6500.0     75.0   162500
# 4031128     .  경기 안성시  12.0 -750   2300.0  -9000.0 -1725000
# 4031129     .  경기 안성시  12.0 -200   2300.0  -2400.0  -460000
# 4031130     .  경기 안성시  12.0  750   1500.0   9000.0  1125000
# 4031131     .  경기 안성시  12.0  200   1500.0   2400.0   300000
#
# [4031132 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20170710   인천구월도매  인천농산물    복숭아     선프레     kg     상자         .
# 1        20170710   인천구월도매  인천농산물    복숭아     선프레     kg     상자         .
# 2        20170710   인천구월도매  인천농산물    복숭아     선프레     kg     상자         .
# 3        20170710   인천구월도매  인천농산물    복숭아     선프레     kg     상자         .
# 4        20170710   인천구월도매  인천농산물    복숭아     선프레     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 4076806  20170731   서울강서도매   강서청과    바나나     바나나     kg      .         .
# 4076807  20170731   서울강서도매   강서청과   파인애플    파인애플     kg      .         .
# 4076808  20170731   서울강서도매   강서청과     오이    백다다기     kg     상자  1개(내_뿌리)
# 4076809  20170731   서울강서도매   강서청과     오이    백다다기     kg     상자  1개(내_뿌리)
# 4076810  20170731   서울강서도매   강서청과     오이    백다다기     kg     상자        2개
#
#         LV_NM      SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           상    경상북도 경산시  10.0   20  13000.0    200.0   260000
# 1          4등    경상북도 경산시  10.0    9   8000.0     90.0    72000
# 2          4등    경상북도 경산시  10.0    5   7000.0     50.0    35000
# 3          4등    경상북도 경산시  10.0    2   6000.0     20.0    12000
# 4          4등    경상북도 경산시  10.0    1   4000.0     10.0     4000
# ...       ...         ...   ...  ...      ...      ...      ...
# 4076806     .  경기 성남시 분당구  13.0   60   7500.0    780.0   450000
# 4076807     .      서울 송파구  10.0   80   9500.0    800.0   760000
# 4076808     .      강원 홍천군  18.0   -9  48000.0   -162.0  -432000
# 4076809     .      강원 홍천군  18.0    8  48000.0    144.0   384000
# 4076810     .      강원 홍천군  18.0    1  23000.0     18.0    23000
#
# [4076811 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20170810   인천구월도매  인천농산물     자두    기타자두     kg     상자         .
# 1        20170810   인천구월도매  인천농산물     자두    기타자두     kg     상자         .
# 2        20170810   인천구월도매  인천농산물     자두    기타자두     kg     상자         .
# 3        20170810   인천구월도매  인천농산물     자두    기타자두     kg     상자         .
# 4        20170810   인천구월도매  인천농산물     자두    기타자두     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 4076940  20170831   서울강서도매   강서청과      무     기타무     kg      .        2개
# 4076941  20170831   서울강서도매   강서청과      무     기타무     kg      .  1개(내_뿌리)
# 4076942  20170831   서울강서도매   강서청과      무     기타무     kg      .  1개(내_뿌리)
# 4076943  20170831   서울강서도매   강서청과      무     기타무     kg      .        2개
# 4076944  20170831   서울강서도매   강서청과      무     기타무     kg      .        2개
#
#         LV_NM    SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           상  경상북도 의성군   5.0   12  27500.0     60.0   330000
# 1           상  경상북도 의성군   5.0    7  20000.0     35.0   140000
# 2          4등  경상북도 의성군   5.0    2  16000.0     10.0    32000
# 3          4등  경상북도 의성군   5.0    1  12000.0      5.0    12000
# 4           특  경상북도 의성군   5.0   26  41000.0    130.0  1066000
# ...       ...       ...   ...  ...      ...      ...      ...
# 4076940     .    강원 평창군  20.0  -10   9750.0   -200.0   -97500
# 4076941     .    강원 평창군  20.0  300  19500.0   6000.0  5850000
# 4076942     .    강원 평창군  20.0   50  19500.0   1000.0   975000
# 4076943     .    강원 평창군  20.0  180   9750.0   3600.0  1755000
# 4076944     .    강원 평창군  20.0   10   9750.0    200.0    97500
#
# [4076945 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20170909   인천구월도매  인천농산물     포도    캠벨얼리     kg     상자       .    4등
# 1        20170909   인천구월도매  인천농산물     포도    캠벨얼리     kg     상자       .    4등
# 2        20170909   인천구월도매  인천농산물     사과      홍로     kg     상자       .     상
# 3        20170909   인천구월도매  인천농산물     사과      홍로     kg     상자       .     상
# 4        20170909   인천구월도매  인천농산물     사과      홍로     kg     상자       .     상
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 4124452  20170930   서울강서도매   강서청과     양파  양파(수입)     kg      접       .     .
# 4124453  20170930   서울강서도매   강서청과     양파  양파(수입)     kg      접       .     .
# 4124454  20170930   서울강서도매   강서청과     양파  양파(수입)     kg      접       .     .
# 4124455  20170930   서울강서도매   강서청과     양파  양파(수입)     kg      접       .     .
# 4124456  20170930   서울강서도매   강서청과     양파  양파(수입)     kg      접       .     .
#
#            SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0         경기도 안산시   5.1   10   9500.0     51.0    95000
# 1         경기도 안산시   5.1    7   7500.0     35.7    52500
# 2        충청남도 예산군  10.0    1  23000.0     10.0    23000
# 3        충청남도 예산군  10.0   11  24000.0    110.0   264000
# 4        충청남도 예산군  10.0    8  23000.0     80.0   184000
# ...           ...   ...  ...      ...      ...      ...
# 4124452    서울 송파구  15.0  -50  13200.0   -750.0  -660000
# 4124453    서울 송파구  15.0   50  13200.0    750.0   660000
# 4124454    서울 송파구  15.0   30  13200.0    450.0   396000
# 4124455    서울 송파구  15.0   20  13200.0    300.0   264000
# 4124456    서울 송파구  15.0   50  13200.0    750.0   660000
#
# [4124457 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20171010   인천구월도매  인천농산물     사과    기타사과     kg     상자         .
# 1        20171010   인천구월도매  인천농산물     사과    기타사과     kg     상자         .
# 2        20171010   인천구월도매  인천농산물     사과    기타사과     kg     상자         .
# 3        20171010   인천구월도매  인천농산물     사과    기타사과     kg     상자         .
# 4        20171010   인천구월도매  인천농산물     사과    기타사과     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 3037167  20171031   서울강서도매   강서청과    양송이   기타양송이     kg    NaN  1개(내_뿌리)
# 3037168  20171031   서울강서도매   강서청과    양송이   기타양송이     kg    NaN  1개(내_뿌리)
# 3037169  20171031   서울강서도매   강서청과    양송이   기타양송이     kg    NaN  1개(내_뿌리)
# 3037170  20171031   서울강서도매   강서청과    양송이   기타양송이     kg    NaN  1개(내_뿌리)
# 3037171  20171031   서울강서도매   강서청과    양송이   기타양송이     kg    NaN  1개(내_뿌리)
#
#         LV_NM    SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           특  경상북도 의성군  10.0   15  28000.0    150.0   420000
# 1           상  경상북도 의성군  10.0   12  25000.0    120.0   300000
# 2           상  경상북도 의성군  10.0   12  23500.0    120.0   282000
# 3          보통  경상북도 의성군  10.0    4  19500.0     40.0    78000
# 4          4등  경상북도 의성군  10.0    4  15000.0     40.0    60000
# ...       ...       ...   ...  ...      ...      ...      ...
# 3037167     .    서울 강서구   2.0  -16  13000.0    -32.0  -208000
# 3037168     .    서울 강서구   2.0  -13  13000.0    -26.0  -169000
# 3037169     .    충남 부여군   2.0   24   9000.0     48.0   216000
# 3037170     .    충남 부여군   2.0   16  13000.0     32.0   208000
# 3037171     .    충남 부여군   2.0   13  13000.0     26.0   169000
#
# [3037172 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20171110   수원도매시장   수원청과    비타민  비타민(일반)     kg      .         .
# 1        20171110   수원도매시장   수원청과  얼갈이배추    얼갈이배추     kg      .         .
# 2        20171110   수원도매시장   수원청과  얼갈이배추    얼갈이배추     kg      .         .
# 3        20171110   수원도매시장   수원청과     쑥갓   쑥갓(일반)     kg      .         .
# 4        20171110   수원도매시장   수원청과     배추      쌈배추     kg      .         .
# ...           ...      ...    ...    ...      ...    ...    ...       ...
# 3090601  20171130   서울강서도매   강서청과     배추     절임배추     kg     상자  1개(내_뿌리)
# 3090602  20171130   서울강서도매   강서청과     배추     절임배추     kg     상자  1개(내_뿌리)
# 3090603  20171130   서울강서도매   강서청과     배추     절임배추     kg     상자  1개(내_뿌리)
# 3090604  20171130   서울강서도매   강서청과     배추     절임배추     kg     상자  1개(내_뿌리)
# 3090605  20171130   서울강서도매   강서청과    시금치  시금치(일반)     kg     상자  1개(내_뿌리)
#
#         LV_NM      SAN_NM  DANQ  QTY     COST  TOT_QTY   TOT_AMT
# 0           .      경기 이천시   2.0    8   3600.0     16.0     28800
# 1           .      경기 이천시   4.0   25   1700.0    100.0     42500
# 2           .      경기 이천시   4.0   25   1700.0    100.0     42500
# 3           .  경기 용인시 처인구   4.0   25   2000.0    100.0     50000
# 4           .  경기 용인시 처인구   1.0    8   1500.0      8.0     12000
# ...       ...         ...   ...  ...      ...      ...       ...
# 3090601     .      전남 해남군  20.0  478  22000.0   9560.0  10516000
# 3090602     .      전남 해남군  20.0   60  22000.0   1200.0   1320000
# 3090603     .      전남 해남군  20.0    7  22000.0    140.0    154000
# 3090604     .      전남 해남군  20.0   20  22000.0    400.0    440000
# 3090605     .      서울 강서구   4.0  -74   3600.0   -296.0   -266400
#
# [3090606 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20171209   수원도매시장   수원청과    풋고추     롱그린     kg      .       .     특
# 1        20171209   수원도매시장   수원청과    풋고추     롱그린     kg      .       .     특
# 2        20171209   수원도매시장   수원청과    풋고추     롱그린     kg      .       .     특
# 3        20171209   수원도매시장   수원청과    풋고추     롱그린     kg      .       .     상
# 4        20171209   수원도매시장   수원청과    풋고추     롱그린     kg      .       .     상
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2752570  20171230   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2752571  20171230   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2752572  20171230   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2752573  20171230   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
# 2752574  20171230   서울강서도매   강서청과    바나나     바나나     kg      .       .     .
#
#          SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0        경남 창녕군  10.0    4  16500.0     40.0    66000
# 1        경남 창녕군  10.0    4  16500.0     40.0    66000
# 2        경남 창녕군  13.0    1  21450.0     13.0    21450
# 3        경남 창녕군  10.0    1   8000.0     10.0     8000
# 4        경남 창녕군   8.0    1   6400.0      8.0     6400
# ...         ...   ...  ...      ...      ...      ...
# 2752570  서울 송파구  13.0   10  13000.0    130.0   130000
# 2752571  서울 송파구  13.0    5  13000.0     65.0    65000
# 2752572  서울 송파구  13.0    5  13000.0     65.0    65000
# 2752573  서울 송파구  13.0   13  13000.0    169.0   169000
# 2752574  서울 송파구  13.0   50  14000.0    650.0   700000
#
# [2752575 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20180110   전주도매시장   전주청과     감귤    기타감귤     kg     상자       .     특
# 1        20180110   전주도매시장   전주청과     감귤    기타감귤     kg     상자       .     특
# 2        20180110   전주도매시장   전주청과     감귤    기타감귤     kg     상자       .     특
# 3        20180110   전주도매시장   전주청과     감귤    기타감귤     kg     상자     16개     특
# 4        20180110   전주도매시장   전주청과     감귤    기타감귤     kg     상자       .     특
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2841233  20180131   서울강서도매   강서청과    양배추   기타양배추     kg      접       .     .
# 2841234  20180131   서울강서도매   강서청과    양배추   기타양배추     kg      접       .     .
# 2841235  20180131   서울강서도매   강서청과    양배추   기타양배추     kg      접       .     .
# 2841236  20180131   서울강서도매   강서청과    양배추   기타양배추     kg      접       .     .
# 2841237  20180131   서울강서도매   강서청과    양배추   기타양배추     kg      접       .     .
#
#          SAN_NM  DANQ  QTY    COST  TOT_QTY  TOT_AMT
# 0           NaN   5.0   25  7500.0    125.0   187500
# 1           NaN   5.0   30  7500.0    150.0   225000
# 2           NaN   5.0   28  6000.0    140.0   168000
# 3           NaN   5.0   21  3500.0    105.0    73500
# 4           NaN   5.0   34  9000.0    170.0   306000
# ...         ...   ...  ...     ...      ...      ...
# 2841233  강원 평창군  10.0   80  3200.0    800.0   256000
# 2841234  강원 평창군  10.0   80  3200.0    800.0   256000
# 2841235  강원 평창군  10.0   80  3200.0    800.0   256000
# 2841236  강원 평창군  10.0   80  3200.0    800.0   256000
# 2841237  강원 평창군  10.0   44  3200.0    440.0   140800
#
# [2841238 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20180210   전주도매시장   전주청과     사과      후지     kg     상자         .
# 1        20180210   전주도매시장   전주청과     사과      후지     kg     상자         .
# 2        20180210   전주도매시장   전주청과     사과      후지     kg     상자         .
# 3        20180210   전주도매시장   전주청과     사과      후지     kg     상자         .
# 4        20180210   전주도매시장   전주청과     사과      후지     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 2691356  20180228   서울강서도매   강서청과    시금치     포항초     kg    PE대  1개(내_뿌리)
# 2691357  20180228   서울강서도매   강서청과      무     기타무     kg    NaN         .
# 2691358  20180228   서울강서도매   강서청과      무     기타무     kg    NaN         .
# 2691359  20180228   서울강서도매   강서청과      무     기타무     kg    NaN         .
# 2691360  20180228   서울강서도매   강서청과      무     기타무     kg    NaN         .
#
#         LV_NM     SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           특        NaN   5.0   50  22000.0    250.0  1100000
# 1           특        NaN   5.0   20  32000.0    100.0   640000
# 2           특        NaN   5.0   70  23000.0    350.0  1610000
# 3           특        NaN   5.0   10  18500.0     50.0   185000
# 4           특        NaN   5.0   20  32000.0    100.0   640000
# ...       ...        ...   ...  ...      ...      ...      ...
# 2691356     .  경북 포항시 북구   0.5  288    800.0    144.0   230400
# 2691357     .    제주 서귀포시  20.0 -264  13000.0  -5280.0 -3432000
# 2691358     .    제주 서귀포시  20.0  264  13000.0   5280.0  3432000
# 2691359     .    제주 서귀포시  20.0 -264  13000.0  -5280.0 -3432000
# 2691360     .    제주 서귀포시  20.0  264  13000.0   5280.0  3432000
#
# [2691361 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20180310   부산엄궁도매   항도청과    토마토  토마토(일반)     kg     상자       11개
# 1        20180310   부산엄궁도매   항도청과    토마토  토마토(일반)     kg     상자       11개
# 2        20180310   부산엄궁도매   항도청과    토마토  토마토(일반)     kg     상자       11개
# 3        20180310   부산엄궁도매   항도청과    토마토  토마토(일반)     kg     상자       11개
# 4        20180310   부산엄궁도매   항도청과    토마토  토마토(일반)     kg     상자       11개
# ...           ...      ...    ...    ...      ...    ...    ...       ...
# 3257565  20180331   서울강서도매   강서청과    미나리  미나리(일반)     kg    그물망  1개(내_뿌리)
# 3257566  20180331   서울강서도매   강서청과   아보카도     아보카도     kg      .         .
# 3257567  20180331   서울강서도매   강서청과     부추     일반부추     kg    PE대  1개(내_뿌리)
# 3257568  20180331   서울강서도매   강서청과     부추     일반부추     kg    PE대  1개(내_뿌리)
# 3257569  20180331   서울강서도매   강서청과     부추     일반부추     kg    PE대  1개(내_뿌리)
#
#         LV_NM  SAN_NM  DANQ  QTY     COST  TOT_QTY    TOT_AMT
# 0           특   부산광역시   5.0    2   2000.0     10.0     4000.0
# 1           특   부산광역시   5.0    8   8200.0     40.0    65600.0
# 2           특   부산광역시   5.0    5   7500.0     25.0    37500.0
# 3           특   부산광역시   5.0    5   7000.0     25.0    35000.0
# 4           특   부산광역시   5.0    4   6800.0     20.0    27200.0
# ...       ...     ...   ...  ...      ...      ...        ...
# 3257565     .  서울 송파구  20.0   30  70000.0    600.0  2100000.0
# 3257566     .  부산 강서구   6.0   50  23000.0    300.0  1150000.0
# 3257567     .  경남 고성군   0.5 -400    800.0   -200.0  -320000.0
# 3257568     .  경남 고성군   0.5  360    800.0    180.0   288000.0
# 3257569     .  경남 고성군   0.5   40    800.0     20.0    32000.0
#
# [3257570 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM   KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20180410   부산엄궁도매   항도청과   표고버섯  표고버섯(일반)     kg  P-BOX       11개
# 1        20180410   부산엄궁도매   항도청과   표고버섯  표고버섯(일반)     kg  P-BOX       11개
# 2        20180410   부산엄궁도매   항도청과    양상추   양상추(일반)     kg     상자       11개
# 3        20180410   부산엄궁도매   항도청과    양상추   양상추(일반)     kg     상자       12개
# 4        20180410   부산엄궁도매   항도청과    새송이   새송이(일반)     kg     봉지       11개
# ...           ...      ...    ...    ...       ...    ...    ...       ...
# 3270185  20180430   서울강서도매   강서청과    바나나       바나나     kg      .  1개(내_뿌리)
# 3270186  20180430   서울강서도매   강서청과    바나나       바나나     kg      .  1개(내_뿌리)
# 3270187  20180430   서울강서도매   강서청과    바나나       바나나     kg      .  1개(내_뿌리)
# 3270188  20180430   서울강서도매   강서청과    바나나       바나나     kg      .  1개(내_뿌리)
# 3270189  20180430   서울강서도매   강서청과    바나나       바나나     kg      .  1개(내_뿌리)
#
#         LV_NM    SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0           특  경상남도 김해시  19.1    1  36290     19.1    36290
# 1           특  경상남도 김해시  18.1    1  34390     18.1    34390
# 2           특     부산광역시   8.0   78   6600    624.0   514800
# 3           상     부산광역시   8.0    2   3600     16.0     7200
# 4           특  경상남도 창녕군   2.0  150   3300    300.0   495000
# ...       ...       ...   ...  ...    ...      ...      ...
# 3270185     .    서울 강남구  13.0   70  12000    910.0   840000
# 3270186     .    서울 강남구  13.0   60  27000    780.0  1620000
# 3270187     .    서울 강남구  13.0   70  27000    910.0  1890000
# 3270188     .    서울 강남구  13.0   60  27000    780.0  1620000
# 3270189     .    서울 강남구  13.0  120  30000   1560.0  3600000
#
# [3270190 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM      PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20180510   전주도매시장   전주청과          참외    노랑참외     kg     상자         .
# 1        20180510   전주도매시장   전주청과          참외    노랑참외     kg     상자         .
# 2        20180510   전주도매시장   전주청과          참외    노랑참외     kg     상자         .
# ...
# 3497401     .  강원 춘천시  20.0   42  10000.0    840.0   420000
#
# [3497402 rows x 15 columns]
#          SALEDATE WHSAL_NM  CMP_NM PUM_NM  KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20181010   부산반여도매  부산중앙청과     포도   포도(수입)     kg     상자         .
# 1        20181010   부산반여도매  부산중앙청과     포도   포도(수입)     kg     상자         .
# 2        20181010   부산반여도매  부산중앙청과     포도   포도(수입)     kg     상자         .
# 3        20181010   부산반여도매  부산중앙청과     포도   포도(수입)     kg     상자         .
# 4        20181010   부산반여도매  부산중앙청과     포도   포도(수입)     kg     상자         .
# ...           ...      ...     ...    ...      ...    ...    ...       ...
# 3560274  20181031   서울강서도매    강서청과     오이     백다다기     kg     상자  1개(내_뿌리)
# 3560275  20181031   서울강서도매    강서청과    양상추  양상추(일반)     kg     상자         .
# 3560276  20181031   서울강서도매    강서청과    양상추  양상추(일반)     kg     상자  1개(내_뿌리)
# 3560277  20181031   서울강서도매    강서청과    양상추  양상추(일반)     kg     상자         .
# 3560278  20181031   서울강서도매    강서청과    양상추  양상추(일반)     kg     상자  1개(내_뿌리)
#
#         LV_NM  SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0           특  경북 영천시   5.0   30  14000    150.0   420000
# 1           특  경북 영천시   5.0   30  14000    150.0   420000
# 2           특  경북 영천시   5.0   30  14000    150.0   420000
# 3           특  경북 영천시   5.0    6  14000     30.0    84000
# 4           특  경북 영천시   5.0   30  15200    150.0   456000
# ...       ...     ...   ...  ...    ...      ...      ...
# 3560274     .  충남 부여군  18.0    3  12000     54.0    36000
# 3560275     .  서울 송파구  10.0  -40  14000   -400.0  -560000
# 3560276     .  서울 송파구  10.0 -163  18000  -1630.0 -2934000
# 3560277     .  서울 송파구  10.0   40  18000    400.0   720000
# 3560278     .  서울 송파구  10.0  163  14000   1630.0  2282000
#
# [3560279 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM   KIND_NM DAN_NM POJ_NM SIZE_NM  \
# 0        20181110   천안도매시장   천안청과    양상추     기타양상추     kg     상자       .
# 1        20181110   천안도매시장   천안청과    양상추     기타양상추     kg     상자       .
# 2        20181110   천안도매시장   천안청과    양상추     기타양상추     kg     상자       .
# 3        20181110   천안도매시장   천안청과    양상추     기타양상추     kg     상자       .
# 4        20181110   천안도매시장   천안청과    양상추     기타양상추     kg     상자       .
# ...           ...      ...    ...    ...       ...    ...    ...     ...
# 3040770  20181130   서울강서도매   강서청과     배추  김장(가을)배추     kg      접       .
# 3040771  20181130   서울강서도매   강서청과     배추  김장(가을)배추     kg      접       .
# 3040772  20181130   서울강서도매   강서청과     배추  김장(가을)배추     kg      접       .
# 3040773  20181130   서울강서도매   강서청과     배추  김장(가을)배추     kg      접       .
# 3040774  20181130   서울강서도매   강서청과     배추  김장(가을)배추     kg      접       .
#
#         LV_NM  SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0           상  서울 강남구   8.0    1  21300.0      8.0    21300
# 1           상  서울 강남구   8.0    2  21300.0     16.0    42600
# 2           상  서울 강남구   8.0    1  21300.0      8.0    21300
# 3           상  서울 강남구   8.0    4  21300.0     32.0    85200
# 4           상  서울 강남구   8.0    6  21300.0     48.0   127800
# ...       ...     ...   ...  ...      ...      ...      ...
# 3040770     .  전북 고창군  12.0 -373   2000.0  -4476.0  -746000
# 3040771     .  전북 고창군  12.0  119   3200.0   1428.0   380800
# 3040772     .  전북 고창군  12.0   33   1900.0    396.0    62700
# 3040773     .  전북 고창군  12.0  382   2000.0   4584.0   764000
# 3040774     .  전북 고창군  12.0  382   2000.0   4584.0   764000
#
# [3040775 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20181210   천안도매시장   천안청과     감자      수미     kg     상자       .     상
# 1        20181210   천안도매시장   천안청과     감자      수미     kg     상자       .     상
# 2        20181210   천안도매시장   천안청과     감자      수미     kg     상자       .     상
# 3        20181210   천안도매시장   천안청과     감자      수미     kg     상자       .     상
# 4        20181210   천안도매시장   천안청과     감자      수미     kg     상자       .     상
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2863302  20181231   서울강서도매   강서청과     깻잎  깻잎(일반)     kg     상자       .    보통
# 2863303  20181231   서울강서도매   강서청과     깻잎  깻잎(일반)     kg     상자       .    보통
# 2863304  20181231   서울강서도매   강서청과     깻잎  깻잎(일반)     kg     상자       .    보통
# 2863305  20181231   서울강서도매   강서청과     깻잎  깻잎(일반)     kg     상자       .    보통
# 2863306  20181231   서울강서도매   강서청과     깻잎  깻잎(일반)     kg     상자       .     특
#
#          SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0        강원 횡성군  20.0    3  23000.0     60.0    69000
# 1        강원 횡성군  20.0    4  10600.0     80.0    42400
# 2        강원 횡성군  20.0    2   5000.0     40.0    10000
# 3        강원 횡성군  20.0    2  35000.0     40.0    70000
# 4        강원 횡성군  20.0    2  30000.0     40.0    60000
# ...         ...   ...  ...      ...      ...      ...
# 2863302  대전 대덕구   3.0   10   8500.0     30.0    85000
# 2863303  대전 대덕구   3.0    6  10000.0     18.0    60000
# 2863304  대전 대덕구   3.0    5  10200.0     15.0    51000
# 2863305  대전 대덕구   3.0    5  11000.0     15.0    55000
# 2863306  대전 대덕구   3.0   10  11500.0     30.0   115000
#
# [2863307 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM   KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20190110   대구북부도매   대양청과     오이      가시오이     kg     상자         .
# 1        20190110   대구북부도매   대양청과     오이      가시오이     kg     상자         .
# 2        20190110   대구북부도매   대양청과     오이      가시오이     kg     상자         .
# 3        20190110   대구북부도매   대양청과     오이      가시오이     kg     상자         .
# 4        20190110   대구북부도매   대양청과     오이      가시오이     kg     상자         .
# ...           ...      ...    ...    ...       ...    ...    ...       ...
# 3218989  20190131   서울강서도매   강서청과   체리모야  체리모야(일반)     kg      .  1개(내_뿌리)
# 3218990  20190131   서울강서도매   강서청과     호박   단호박(수입)     kg     상자         .
# 3218991  20190131   서울강서도매   강서청과     호박   단호박(수입)     kg     상자         .
# 3218992  20190131   서울강서도매   강서청과    시금치   시금치(일반)     kg    PE대         .
# 3218993  20190131   서울강서도매   강서청과    시금치   시금치(일반)     kg    PE대         .
#
#         LV_NM     SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0          등외   경상북도 구미시  10.0    1   6000     10.0     6000
# 1           특  대구광역시 달성군  10.0   20  18000    200.0   360000
# 2           상  대구광역시 달성군  10.0   16  14500    160.0   232000
# 3          보통  대구광역시 달성군  10.0   12  11500    120.0   138000
# 4          4등  대구광역시 달성군  10.0    8   5500     80.0    44000
# ...       ...        ...   ...  ...    ...      ...      ...
# 3218989     .     경기 구리시   5.0    4  45000     20.0   180000
# 3218990     .     부산 강서구  10.0  -20  26000   -200.0  -520000
# 3218991     .     부산 강서구  10.0   16  26000    160.0   416000
# 3218992     .     경남 하동군   0.5 -750   1160   -375.0  -870000
# 3218993     .     경남 하동군   0.5  750   1000    375.0   750000
#
# [3218994 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20190209   대구북부도매   대양청과     호박   쥬키니호박     kg     상자       .    등외
# 1        20190209   대구북부도매   대양청과     호박   쥬키니호박     kg     상자       .    보통
# 2        20190209   대구북부도매   대양청과     호박   쥬키니호박     kg     상자       .    4등
# 3        20190209   대구북부도매   대양청과     쪽파     깐쪽파     kg     상자       .     특
# 4        20190209   대구북부도매   대양청과     가지  가지(일반)     kg     상자       .     특
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2318719  20190228   서울강서도매   강서청과    오렌지      네블     kg      .       .     .
# 2318720  20190228   서울강서도매   강서청과    오렌지      네블     kg      .       .     .
# 2318721  20190228   서울강서도매   강서청과    오렌지      네블     kg      .       .     .
# 2318722  20190228   서울강서도매   강서청과    오렌지      네블     kg      .       .     .
# 2318723  20190228   서울강서도매   강서청과    오렌지      네블     kg      .       .     .
#
#            SAN_NM  DANQ  QTY   COST  TOT_QTY  TOT_AMT
# 0        경상북도 성주군  10.0   25   4500    250.0   112500
# 1        경상북도 성주군  10.0   27   4000    270.0   108000
# 2        경상북도 성주군  10.0    2   2000     20.0     4000
# 3         제주도 제주시  10.0    1  45000     10.0    45000
# 4        경상남도 밀양시   5.0   45  12000    225.0   540000
# ...           ...   ...  ...    ...      ...      ...
# 2318719    서울 구로구  18.0  -15  48000   -270.0  -720000
# 2318720    서울 구로구  18.0  -16  48000   -288.0  -768000
# 2318721    서울 구로구  18.0   12  48000    216.0   576000
# 2318722    서울 구로구  18.0   16  48000    288.0   768000
# 2318723    서울 구로구  18.0   14  48000    252.0   672000
#
# [2318724 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM        PUM_NM   KIND_NM DAN_NM POJ_NM  \
# 0        20190309   대구북부도매   대양청과  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
# 1        20190309   대구북부도매   대양청과  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
# 2        20190309   대구북부도매   대양청과  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
# 3        20190309   대구북부도매   대양청과  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
# 4        20190309   대구북부도매   대양청과  브로코리(녹색꽃양배추)  브로코리(일반)     kg     상자
# ...           ...      ...    ...           ...       ...    ...    ...
# 3188902  20190330   서울강서도매   강서청과            마늘       깐마늘     kg    파렛트
# 3188903  20190330   서울강서도매   강서청과            마늘       깐마늘     kg    파렛트
# 3188904  20190330   서울강서도매   강서청과           풋고추        청양     kg     상자
# 3188905  20190330   서울강서도매   강서청과           풋고추        청양     kg     상자
# 3188906  20190330   서울강서도매   강서청과           풋고추        청양     kg     상자
#
#           SIZE_NM LV_NM   SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0               .     특  제주도 제주시   8.0   10  15500.0     80.0   155000
# 1               .     특  제주도 제주시   8.0    5  15500.0     40.0    77500
# 2               .    등외  제주도 제주시   8.0    9  13000.0     72.0   117000
# 3               .    등외  제주도 제주시   8.0   11  13000.0     88.0   143000
# 4               .    등외  제주도 제주시   8.0    1  13000.0      8.0    13000
# ...           ...   ...      ...   ...  ...      ...      ...      ...
# 3188902       13개     .   서울 강서구  20.0   30  98000.0    600.0  2940000
# 3188903       20개     .   서울 강서구  20.0   40  52000.0    800.0  2080000
# 3188904  1개(내_뿌리)     .   경남 진주시  10.0  -11  41000.0   -110.0  -451000
# 3188905  1개(내_뿌리)     .   경남 진주시  10.0   10  41000.0    100.0   410000
# 3188906  1개(내_뿌리)     .   경남 진주시  10.0    1  36000.0     10.0    36000
#
# [3188907 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0        20190410   대구북부도매   대양청과    토마토   완숙토마토     kg     상자       .    등외
# 1        20190410   대구북부도매   대양청과    토마토   완숙토마토     kg     상자       .    등외
# 2        20190410   대구북부도매   대양청과    토마토   완숙토마토     kg     상자       .    등외
# 3        20190410   대구북부도매   대양청과    토마토   완숙토마토     kg     상자       .    등외
# 4        20190410   대구북부도매   대양청과    토마토   완숙토마토     kg     상자       .    등외
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 3433601  20190430   서울강서도매   강서청과     기타   양채류기타     kg    파렛트       .     .
# 3433602  20190430   서울강서도매   강서청과     기타   양채류기타     kg    파렛트       .     .
# 3433603  20190430   서울강서도매   강서청과     기타   양채류기타     kg    파렛트       .     .
# 3433604  20190430   서울강서도매   강서청과     기타   양채류기타     kg    파렛트       .     .
# 3433605  20190430   서울강서도매   강서청과     기타   양채류기타     kg    파렛트       .     .
#
#            SAN_NM  DANQ  QTY    COST  TOT_QTY  TOT_AMT
# 0        경상남도 합천군   5.0   63  9800.0    315.0   617400
# 1        경상남도 합천군   5.0   19  6200.0     95.0   117800
# 2        경상남도 합천군   5.0   11  5500.0     55.0    60500
# 3        경상남도 합천군   5.0    5  4500.0     25.0    22500
# 4        경상남도 합천군   5.0    1  2500.0      5.0     2500
# ...           ...   ...  ...     ...      ...      ...
# 3433601   제주 서귀포시  20.0  -19  5200.0   -380.0   -98800
# 3433602   제주 서귀포시  20.0  -50  5500.0  -1000.0  -275000
# 3433603   제주 서귀포시  20.0  100  5200.0   2000.0   520000
# 3433604   제주 서귀포시  20.0   19  5200.0    380.0    98800
# 3433605   제주 서귀포시  20.0   50  5500.0   1000.0   275000
#
# [3433606 rows x 15 columns]
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20190510   대구북부도매   대양청과     오이    가시오이     kg     상자         .
# 1        20190510   대구북부도매   대양청과     오이    가시오이     kg     상자         .
# 2        20190510   대구북부도매   대양청과     오이    가시오이     kg     상자         .
# 3        20190510   대구북부도매   대양청과     오이    가시오이     kg     상자         .
# 4        20190510   대구북부도매   대양청과     오이    가시오이     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 3579586  20190531   서울강서도매   강서청과    바나나     바나나     kg      .  1개(내_뿌리)
# 3579587  20190531   서울강서도매   강서청과    바나나     바나나     kg      .  1개(내_뿌리)
# 3579588  20190531   서울강서도매   강서청과    바나나     바나나     kg      .  1개(내_뿌리)
# 3579589  20190531   서울강서도매   강서청과      갓   갓(일반)     kg    PE대  1개(내_뿌리)
# 3579590  20190531   서울강서도매   강서청과      갓   갓(일반)     kg    PE대  1개(내_뿌리)
#
#         LV_NM      SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0          보통      경북 칠곡군  10.0    1  10000.0     10.0    10000
# 1          등외      경북 칠곡군  10.0    3  12000.0     30.0    36000
# 2           특      경북 칠곡군  10.0   21  13000.0    210.0   273000
# 3           상      경북 칠곡군  10.0    9  11500.0     90.0   103500
# 4          보통      경북 칠곡군  10.0    3   9500.0     30.0    28500
# ...       ...         ...   ...  ...      ...      ...      ...
# 3579586     .      서울 서초구  13.0   24  21000.0    312.0   504000
# 3579587     .      서울 서초구  13.0   24  21000.0    312.0   504000
# 3579588     .      서울 서초구  13.0   30  21000.0    390.0   630000
# 3579589     .  경기 고양시 덕양구   2.0 -150    600.0   -300.0   -90000
# 3579590     .  경기 고양시 덕양구   2.0  150    600.0    300.0    90000
#
# [3579591 rows x 15 columns]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17952/1056551456.py in <module>
#       3 for train in train_list:
#       4     current_data = pd.read_csv(train)
# ----> 5     train_at = pd.concat([train_at,current_data])
#       6     print(current_data)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in get_result(self)
#     530                 mgrs_indexers.append((obj._mgr, indexers))
#     531
# --> 532             new_data = concatenate_managers(
#     533                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     534             )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     224             fastpath = blk.values.dtype == values.dtype
#     225         else:
# --> 226             values = _concatenate_join_units(join_units, concat_axis, copy=copy)
#     227             fastpath = False
#     228
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\concat.py in _concatenate_join_units(join_units, concat_axis, copy)
#     521
#     522     else:
# --> 523         concat_values = concat_compat(to_concat, axis=concat_axis)
#     524
#     525     return concat_values
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\concat.py in concat_compat(to_concat, axis, ea_compat_axis)
#     149                 to_concat = [x.astype("object") for x in to_concat]
#     150
# --> 151     return np.concatenate(to_concat, axis=axis)
#     152
#     153
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 1.05 GiB for an array with shape (1, 140976602) and data type float64

# %%
train_at
# Out:
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM   SIZE_NM  \
# 0        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자         .
# 1        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자         .
# 2        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자         .
# 3        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자         .
# 4        20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자         .
# ...           ...      ...    ...    ...     ...    ...    ...       ...
# 3579586  20190531   서울강서도매   강서청과    바나나     바나나     kg      .  1개(내_뿌리)
# 3579587  20190531   서울강서도매   강서청과    바나나     바나나     kg      .  1개(내_뿌리)
# 3579588  20190531   서울강서도매   강서청과    바나나     바나나     kg      .  1개(내_뿌리)
# 3579589  20190531   서울강서도매   강서청과      갓   갓(일반)     kg    PE대  1개(내_뿌리)
# 3579590  20190531   서울강서도매   강서청과      갓   갓(일반)     kg    PE대  1개(내_뿌리)
#
#         LV_NM      SAN_NM  DANQ  QTY     COST  TOT_QTY   TOT_AMT
# 0          보통     제주도 제주시  10.0   62  14400.0    620.0  892800.0
# 1          보통     제주도 제주시  10.0   29  14700.0    290.0  426300.0
# 2           특     제주도 제주시  10.0   17  12800.0    170.0  217600.0
# 3           특     제주도 제주시  10.0   16   8800.0    160.0  140800.0
# 4          보통     제주 남제주군  10.0   25   7300.0    250.0  182500.0
# ...       ...         ...   ...  ...      ...      ...       ...
# 3579586     .      서울 서초구  13.0   24  21000.0    312.0  504000.0
# 3579587     .      서울 서초구  13.0   24  21000.0    312.0  504000.0
# 3579588     .      서울 서초구  13.0   30  21000.0    390.0  630000.0
# 3579589     .  경기 고양시 덕양구   2.0 -150    600.0   -300.0  -90000.0
# 3579590     .  경기 고양시 덕양구   2.0  150    600.0    300.0   90000.0
#
# [137273904 rows x 15 columns]

# %%
train_at.to_csv('train_at.csv',index=False)
