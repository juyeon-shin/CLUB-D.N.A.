# %% [markdown]
# <a href="https://colab.research.google.com/github/juyeon-shin/CLUB-D.N.A./blob/main/2022/03.%20%EB%86%8D%EC%82%B0%EB%AC%BC%20%EA%B0%80%EA%B2%A9%20%EC%98%88%EC%B8%A1%20AI%20%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8C/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('/content/drive/MyDrive/2022/202201 펭귄 몸무게 예측 경진대회/데이터/train.csv')

# %%
train
# Out:
#       id                                    Species     Island  \
# 0      0          Gentoo penguin (Pygoscelis papua)     Biscoe
# 1      1  Chinstrap penguin (Pygoscelis antarctica)      Dream
# 2      2          Gentoo penguin (Pygoscelis papua)     Biscoe
# 3      3          Gentoo penguin (Pygoscelis papua)     Biscoe
# 4      4          Gentoo penguin (Pygoscelis papua)     Biscoe
# ..   ...                                        ...        ...
# 109  109        Adelie Penguin (Pygoscelis adeliae)  Torgersen
# 110  110        Adelie Penguin (Pygoscelis adeliae)      Dream
# 111  111        Adelie Penguin (Pygoscelis adeliae)      Dream
# 112  112  Chinstrap penguin (Pygoscelis antarctica)      Dream
# 113  113          Gentoo penguin (Pygoscelis papua)     Biscoe
#
#     Clutch Completion  Culmen Length (mm)  Culmen Depth (mm)  \
# 0                 Yes                50.0               15.3
# 1                  No                49.5               19.0
# ...
