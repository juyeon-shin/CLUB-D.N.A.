# %% [markdown]
# ## 상권분석 뉴스 크롤링
# ### 1. 데이터 불러오기
# 관악구, 동작구, 금천구 크롤링

# %%
# !pip install selenium
# !pip install bs4
# !pip install --upgrade setuptools
#패키지 설치, 한번만 실행
# Out:
# Requirement already satisfied: selenium in c:\users\juyeo\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\juyeo\anaconda3\lib\site-packages (from selenium) (1.25.11)
# Requirement already satisfied: bs4 in c:\users\juyeo\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\juyeo\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\juyeo\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already up-to-date: setuptools in c:\users\juyeo\anaconda3\lib\site-packages (56.2.0)

# %%
import urllib.request
from selenium import webdriver
import urllib.parse
from bs4 import BeautifulSoup
import requests
import csv
import re

# %% [markdown]
# ### 2. 뉴스 크롤링

# %%
def get_news_links(page_num, link_pattern):
    links = []
    for page in range(page_num):
        print(f"Scrapping page: {page+1}") # 확인용
        req = requests.get(f"{URL}&start={10*page+1}"); print(req.status_code)
        soup = BeautifulSoup(req.text, 'lxml')
        results = soup.find_all('a', {'href': re.compile(link_pattern)})
        for result in results:
            links.append(result['href'])
    print(f"총 {len(links)}개의 뉴스 링크를 찾았습니다.") # 확인용
    return links

# %%
QUERY = "금천구 상권" # 키워드
search_QUERY = urllib.parse.urlencode({'query':QUERY}, encoding='utf-8')
URL = f"https://search.naver.com/search.naver?&where=news&{search_QUERY}&sm=tab_pge&sort=0&photo=0&field=0&reporter_article=&pd=3&ds=2020.05.01&de=2021.04.30&docid=&nso=so:r,p:from20210101to20210331,a:all&mynews=0"
# 기간 설정
# url 날짜 변경 &pd=3&ds=2020.05.01&de=2021.04.30&docid=&nso=so:r,p:from20210101to20210331 
# ds(시작날짜), de(끝나는날짜), from(시작날짜), to(끝나는날짜)

LINK_PAT = "https:\/\/news\.naver\.com\/main\/read\.nhn\?"
search_PAGE = 400 # 최대 400 (한페이지당 12)

# %%
def extract_info(url, wait_time=1, delay_time=0.3):
    driver.implicitly_wait(wait_time)
    driver.get(url)

    # html 페이지 읽어오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    
    try:
        
        title = soup.find('h3', {'id':'articleTitle'}).get_text(strip=True)
        
        contents = soup.find_all("div", {"class":"_article_body_contents"})
        contents = [content.text for content in contents]
        
        print("완료", end=' ') # 확인용
        return {'site':url, 'title':title, 'contents':contents}

    except:
        print("오류", end=' ')
        return {'site':None, 'title':None, 'contents':None}

# %%
# 각 페이지 돌면서 스크레이핑

def extract_contents(links):
    contents = []
    a = 1
    for link in links:
        content = extract_info(f"{link}") # 각 링크에 대해 extract_info함수 추출
        print(a)
        contents.append(content) # 결과 저장
        a += 1
    return contents

# %%
def save_to_file(lst):
    file = open("C:/Users/juyeo/Desktop/store/news_contents_Naver.csv", mode="w", encoding="utf-8-sig")
    # file 저장 주소 변경 -> 결과 csv 파일 저장 경로
    writer = csv.writer(file)
    writer.writerow(['site', 'title', 'contents'])
    for result in lst:
        writer.writerow(list(result.values()))
    file.close()
    return

# %%
# main 함수

def main():
    last_page = search_PAGE
    news_links = get_news_links(search_PAGE, LINK_PAT)
    result = extract_contents(news_links)
    driver.quit()
    return result

# %%
path = "C:/chromedriver_win32/chromedriver.exe" # 크롬 드라이버 경로 (본인 크롬 드라이브 저장되어 있는 경로로 변경)
driver = webdriver.Chrome(path)

NAVER_RESULT = main()
save_to_file(NAVER_RESULT)
# Out:
# Scrapping page: 1
# 200
# Scrapping page: 2
# 200
# Scrapping page: 3
# 200
# Scrapping page: 4
# 200
# Scrapping page: 5
# 200
# Scrapping page: 6
# 200
# Scrapping page: 7
# 200
# Scrapping page: 8
# 200
# Scrapping page: 9
# 200
# Scrapping page: 10
# 200
# Scrapping page: 11
# 200
# Scrapping page: 12
# 200
# Scrapping page: 13
# 200
# Scrapping page: 14
# 200
# Scrapping page: 15
# 200
# Scrapping page: 16
# 200
# Scrapping page: 17
# 200
# Scrapping page: 18
# 200
# Scrapping page: 19
# 200
# Scrapping page: 20
# 200
# Scrapping page: 21
# 200
# Scrapping page: 22
# 200
# Scrapping page: 23
# 200
# Scrapping page: 24
# 200
# Scrapping page: 25
# 200
# Scrapping page: 26
# 200
# Scrapping page: 27
# 200
# Scrapping page: 28
# 200
# Scrapping page: 29
# 200
# Scrapping page: 30
# 200
# Scrapping page: 31
# 200
# Scrapping page: 32
# 200
# Scrapping page: 33
# 200
# Scrapping page: 34
# 200
# Scrapping page: 35
# 200
# Scrapping page: 36
# 200
# Scrapping page: 37
# 200
# Scrapping page: 38
# 200
# Scrapping page: 39
# 200
# Scrapping page: 40
# 200
# Scrapping page: 41
# 200
# Scrapping page: 42
# 200
# Scrapping page: 43
# 200
# Scrapping page: 44
# 200
# Scrapping page: 45
# 200
# Scrapping page: 46
# 200
# Scrapping page: 47
# 200
# Scrapping page: 48
# 200
# Scrapping page: 49
# 200
# Scrapping page: 50
# 200
# Scrapping page: 51
# 200
# Scrapping page: 52
# 200
# Scrapping page: 53
# 200
# Scrapping page: 54
# 200
# Scrapping page: 55
# 200
# Scrapping page: 56
# 200
# Scrapping page: 57
# 200
# Scrapping page: 58
# 200
# Scrapping page: 59
# 200
# Scrapping page: 60
# 200
# Scrapping page: 61
# 200
# Scrapping page: 62
# 200
# Scrapping page: 63
# 200
# Scrapping page: 64
# 200
# Scrapping page: 65
# 200
# Scrapping page: 66
# 200
# Scrapping page: 67
# 200
# Scrapping page: 68
# 200
# Scrapping page: 69
# 200
# Scrapping page: 70
# 200
# Scrapping page: 71
# 200
# Scrapping page: 72
# 200
# Scrapping page: 73
# 200
# Scrapping page: 74
# 200
# Scrapping page: 75
# 200
# Scrapping page: 76
# 200
# Scrapping page: 77
# 200
# Scrapping page: 78
# 200
# Scrapping page: 79
# 200
# Scrapping page: 80
# 200
# Scrapping page: 81
# 200
# Scrapping page: 82
# 200
# Scrapping page: 83
# 200
# Scrapping page: 84
# 200
# Scrapping page: 85
# 200
# Scrapping page: 86
# 200
# Scrapping page: 87
# 200
# Scrapping page: 88
# 200
# Scrapping page: 89
# 200
# Scrapping page: 90
# 200
# Scrapping page: 91
# 200
# Scrapping page: 92
# 200
# Scrapping page: 93
# 200
# Scrapping page: 94
# 200
# Scrapping page: 95
# 200
# Scrapping page: 96
# 200
# Scrapping page: 97
# 200
# Scrapping page: 98
# 200
# Scrapping page: 99
# 200
# Scrapping page: 100
# 200
# Scrapping page: 101
# 200
# Scrapping page: 102
# 200
# Scrapping page: 103
# 200
# Scrapping page: 320
# 200
# Scrapping page: 321
# 200
# Scrapping page: 322
# 200
# Scrapping page: 323
# 200
# Scrapping page: 324
# 200
# Scrapping page: 325
# 200
# Scrapping page: 326
# 200
# Scrapping page: 327
# 200
# Scrapping page: 328
# 200
# Scrapping page: 329
# 200
# Scrapping page: 330
# 200
# Scrapping page: 331
# 200
# Scrapping page: 332
# 200
# Scrapping page: 333
# 200
# Scrapping page: 334
# 200
# Scrapping page: 335
# 200
# Scrapping page: 336
# 200
# Scrapping page: 337
# 200
# Scrapping page: 338
# 200
# Scrapping page: 339
# 200
# Scrapping page: 340
# 200
# Scrapping page: 341
# 200
# Scrapping page: 342
# 200
# Scrapping page: 343
# 200
# Scrapping page: 344
# 200
# Scrapping page: 345
# 200
# Scrapping page: 346
# 200
# Scrapping page: 347
# 200
# Scrapping page: 348
# 200
# Scrapping page: 349
# 200
# Scrapping page: 350
# 200
# Scrapping page: 351
# 200
# Scrapping page: 352
# 200
# Scrapping page: 353
# 200
# Scrapping page: 354
# 200
# Scrapping page: 355
# 200
# Scrapping page: 356
# 200
# Scrapping page: 357
# 200
# Scrapping page: 358
# 200
# Scrapping page: 359
# 200
# Scrapping page: 360
# 200
# Scrapping page: 361
# 200
# Scrapping page: 362
# 200
# Scrapping page: 363
# 200
# Scrapping page: 364
# 200
# Scrapping page: 365
# 200
# Scrapping page: 366
# 200
# Scrapping page: 367
# 200
# Scrapping page: 368
# 200
# Scrapping page: 369
# 200
# Scrapping page: 370
# 200
# Scrapping page: 371
# 200
# Scrapping page: 372
# 200
# Scrapping page: 373
# 200
# Scrapping page: 374
# 200
# Scrapping page: 375
# 200
# Scrapping page: 376
# 200
# Scrapping page: 377
# 200
# Scrapping page: 378
# 200
# Scrapping page: 379
# 200
# Scrapping page: 380
# 200
# Scrapping page: 381
# 200
# Scrapping page: 382
# 200
# Scrapping page: 383
# 200
# Scrapping page: 384
# 200
# Scrapping page: 385
# 200
# Scrapping page: 386
# 200
# Scrapping page: 387
# 200
# Scrapping page: 388
# 200
# Scrapping page: 389
# 200
# Scrapping page: 390
# 200
# Scrapping page: 391
# 200
# Scrapping page: 392
# 200
# Scrapping page: 393
# 200
# Scrapping page: 394
# 200
# Scrapping page: 395
# 200
# Scrapping page: 396
# 200
# Scrapping page: 397
# 200
# Scrapping page: 398
# 200
# Scrapping page: 399
# 200
# Scrapping page: 400
# 200
# 총 286개의 뉴스 링크를 찾았습니다.
# 완료 1
# 완료 2
# 완료 3
# 완료 4
# 완료 5
# 완료 6
# 완료 7
# 완료 8
# 완료 9
# 완료 10
# 완료 11
# 완료 12
# 완료 13
# 완료 14
# 완료 15
# 완료 16
# 완료 17
# 완료 18
# 완료 19
# 완료 20
# 완료 21
# 완료 22
# 완료 23
# 완료 24
# 완료 25
# 완료 26
# 완료 27
# 완료 28
# 완료 29
# 완료 30
# 완료 31
# 완료 32
# 완료 33
# 완료 34
# 완료 35
# 완료 36
# 완료 37
# 완료 38
# 완료 39
# 완료 40
# 완료 41
# 완료 42
# 완료 43
# 완료 44
# 완료 45
# 완료 46
# 완료 47
# 완료 48
# 완료 49
# 완료 50
# 완료 51
# 완료 52
# 완료 53
# 완료 54
# 완료 55
# 완료 56
# 완료 57
# 완료 58
# 완료 59
# 완료 60
# 완료 61
# 완료 62
# 완료 63
# 완료 64
# 완료 65
# 완료 66
# 완료 67
# 완료 68
# 완료 69
# 완료 70
# 완료 71
# 완료 72
# 완료 73
# 완료 74
# 완료 75
# 완료 76
# 완료 77
# 완료 78
# 완료 79
# 완료 80
# 완료 81
# 완료 82
# 완료 83
# 완료 84
# 완료 85
# 완료 86
# 완료 87
# 완료 88
# 완료 89
# 완료 90
# 완료 91
# 완료 92
# 완료 93
# 완료 94
# 완료 95
# 완료 96
# 완료 97
# 완료 98
# 완료 99
# 완료 100
# 완료 101
# 완료 102
# 완료 103
# 완료 104
# 완료 105
# 완료 106
# 완료 107
# 완료 108
# 완료 109
# 완료 110
# 완료 111
# 완료 112
# 완료 113
# 완료 114
# 완료 115
# 완료 116
# 완료 117
# 완료 118
# 완료 119
# 완료 120
# 완료 121
# 완료 122
# 완료 123
# 완료 124
# 완료 125
# 완료 126
# 완료 127
# 완료 128
# 완료 129
# 완료 130
# 완료 131
# 완료 132
# 완료 133
# 완료 134
# 완료 135
# 완료 136
# 완료 137
# 완료 138
# 완료 139
# 완료 140
# 완료 141
# 완료 142
# 완료 143
# 완료 144
# 완료 145
# 완료 146
# 완료 147
# 완료 148
# 완료 149
# 완료 150
# 완료 151
# 완료 152
# 완료 153
# 완료 154
# 완료 155
# 완료 156
# 완료 157
# 완료 158
# 완료 159
# 완료 160
# 완료 161
# 완료 162
# 완료 163
# 완료 164
# 완료 165
# 완료 166
# 완료 167
# 완료 168
# 완료 169
# 완료 170
# 완료 171
# 완료 172
# 완료 173
# 완료 174
# 완료 175
# 완료 176
# 완료 177
# 완료 178
# 완료 179
# 완료 180
# 완료 181
# 완료 182
# 완료 183
# 완료 184
# 완료 185
# 완료 186
# 완료 187
# 완료 188
# 완료 189
# 완료 190
# 완료 191
# 완료 192
# 완료 193
# 완료 194
# 완료 195
# 완료 196
# 완료 197
# 완료 198
# 완료 199
# 완료 200
# 완료 201
# 완료 202
# 완료 203
# 완료 204
# 완료 205
# 완료 206
# 완료 207
# 완료 208
# 완료 209
# 완료 210
# 완료 211
# 완료 212
# 완료 213
# 완료 214
# 완료 215
# 완료 216
# 완료 217
# 완료 218
# 완료 219
# 완료 220
# 완료 221
# 완료 222
# 완료 223
# 완료 224
# 완료 225
# 완료 226
# 완료 227
# 완료 228
# 완료 229
# 완료 230
# 완료 231
# 완료 232
# 완료 233
# 완료 234
# 완료 235
# 완료 236
# 완료 237
# 완료 238
# 완료 239
# 완료 240
# 완료 241
# 완료 242
# 완료 243
# 완료 244
# 완료 245
# 완료 246
# 완료 247
# 완료 248
# 완료 249
# 완료 250
# 완료 251
# 완료 252
# 완료 253
# 완료 254
# 완료 255
# 완료 256
# 완료 257
# 완료 258
# 완료 259
# 완료 260
# 완료 261
# 완료 262
# 완료 263
# 완료 264
# 완료 265
# 완료 266
# 완료 267
# 완료 268
# 완료 269
# 완료 270
# 완료 271
# 완료 272
# 완료 273
# 완료 274
# 완료 275
# 완료 276
# 완료 277
# 완료 278
# 완료 279
# 완료 280
# 완료 281
# 완료 282
# 완료 283
# 완료 284
# 완료 285
# 완료 286
