# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 22 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 1s (9,956 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 128213 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20180306-3_all.deb ...
# Unpacking fonts-nanum (20180306-3) ...
# Setting up fonts-nanum (20180306-3) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import datetime as dt

import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') 
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/따릉이/train.csv')
data.head(10)
# Out:
#          일시    광진구   동대문구    성동구    중랑구
# 0  20180101  0.592  0.368  0.580  0.162
# 1  20180102  0.840  0.614  1.034  0.260
# 2  20180103  0.828  0.576  0.952  0.288
# 3  20180104  0.792  0.542  0.914  0.292
# 4  20180105  0.818  0.602  0.994  0.308
# 5  20180106  0.618  0.522  0.696  0.228
# 6  20180107  0.598  0.478  0.606  0.238
# 7  20180108  0.742  0.528  0.848  0.202
# 8  20180109  0.652  0.488  0.838  0.206
# 9  20180110  0.500  0.406  0.636  0.160

# %%
sub = pd.read_csv('/content/drive/MyDrive/따릉이/sample_submission.csv')
sub
# Out:
#            일시  광진구  동대문구  성동구  중랑구
# 0    20220101    0     0    0    0
# 1    20220102    0     0    0    0
# 2    20220103    0     0    0    0
# 3    20220104    0     0    0    0
# 4    20220105    0     0    0    0
# ..        ...  ...   ...  ...  ...
# 329  20221126    0     0    0    0
# 330  20221127    0     0    0    0
# 331  20221128    0     0    0    0
# 332  20221129    0     0    0    0
# 333  20221130    0     0    0    0
#
# [334 rows x 5 columns]

# %%
len(sub)
# Out:
# 334

# %% [markdown]
# ### 데이터 전처리

# %%
data['일시'] = data['일시'].astype('str')

#data['MS'] = pd.to_datetime(data['일시']).dt.to_period('m')
data['일시'] = pd.to_datetime(data['일시']).dt.date
data = data.set_index('일시')
data.sort_index(inplace=True)
data
# Out:
#               광진구   동대문구    성동구    중랑구
# 일시
# 2018-01-01  0.592  0.368  0.580  0.162
# 2018-01-02  0.840  0.614  1.034  0.260
# 2018-01-03  0.828  0.576  0.952  0.288
# 2018-01-04  0.792  0.542  0.914  0.292
# 2018-01-05  0.818  0.602  0.994  0.308
# ...           ...    ...    ...    ...
# 2021-12-27  3.830  3.416  2.908  2.350
# 2021-12-28  4.510  3.890  3.714  2.700
# 2021-12-29  4.490  3.524  3.660  2.524
# 2021-12-30  4.444  3.574  3.530  2.506
# 2021-12-31  3.616  3.210  2.620  2.146
#
# [1461 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# 광진구     0
# 동대문구    0
# 성동구     0
# 중랑구     0
# dtype: int64

# %%
print(data[data['광진구'] <= 0])
print(data[data['성동구'] <= 0])
print(data[data['동대문구'] <= 0])
print(data[data['중랑구'] <= 0])
# Out:
#             광진구  동대문구  성동구  중랑구
# 일시
# 2019-09-07  0.0   0.0  0.0  0.0
#             광진구  동대문구  성동구  중랑구
# 일시
# 2019-09-07  0.0   0.0  0.0  0.0
#             광진구  동대문구  성동구  중랑구
# 일시
# 2019-09-07  0.0   0.0  0.0  0.0
#             광진구  동대문구  성동구  중랑구
# 일시
# 2019-09-07  0.0   0.0  0.0  0.0

# %%
data.drop(data[data['광진구'] == 0].index, inplace=True)

# %%
data.asfreq(freq='d', method='ffill')
# Out:
#               광진구   동대문구    성동구    중랑구
# 일시
# 2018-01-01  0.592  0.368  0.580  0.162
# 2018-01-02  0.840  0.614  1.034  0.260
# 2018-01-03  0.828  0.576  0.952  0.288
# 2018-01-04  0.792  0.542  0.914  0.292
# 2018-01-05  0.818  0.602  0.994  0.308
# ...           ...    ...    ...    ...
# 2021-12-27  3.830  3.416  2.908  2.350
# 2021-12-28  4.510  3.890  3.714  2.700
# 2021-12-29  4.490  3.524  3.660  2.524
# 2021-12-30  4.444  3.574  3.530  2.506
# 2021-12-31  3.616  3.210  2.620  2.146
#
# [1461 rows x 4 columns]

# %%
print(data[data['광진구'] <= 0])
print(data[data['성동구'] <= 0])
print(data[data['동대문구'] <= 0])
print(data[data['중랑구'] <= 0])
# Out:
# Empty DataFrame
# Columns: [광진구, 동대문구, 성동구, 중랑구]
# Index: []
# Empty DataFrame
# Columns: [광진구, 동대문구, 성동구, 중랑구]
# Index: []
# Empty DataFrame
# Columns: [광진구, 동대문구, 성동구, 중랑구]
# Index: []
# Empty DataFrame
# Columns: [광진구, 동대문구, 성동구, 중랑구]
# Index: []

# %%
data
# Out:
#               광진구   동대문구    성동구    중랑구
# 일시
# 2018-01-01  0.592  0.368  0.580  0.162
# 2018-01-02  0.840  0.614  1.034  0.260
# 2018-01-03  0.828  0.576  0.952  0.288
# 2018-01-04  0.792  0.542  0.914  0.292
# 2018-01-05  0.818  0.602  0.994  0.308
# ...           ...    ...    ...    ...
# 2021-12-27  3.830  3.416  2.908  2.350
# 2021-12-28  4.510  3.890  3.714  2.700
# 2021-12-29  4.490  3.524  3.660  2.524
# 2021-12-30  4.444  3.574  3.530  2.506
# 2021-12-31  3.616  3.210  2.620  2.146
#
# [1460 rows x 4 columns]

# %% [markdown]
# ### 딥러닝 전처리

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data['광진구'], test_size=0.2, shuffle=False)

# %%
def split_data(data, n_step_in, n_step_out):
  x,y = list(), list()
  
  for i in range(len(data)):
    start_idx = i + n_step_in
    end_idx = start_idx + n_step_out
    if end_idx > len(data):
      break

    data_x, data_y = data[i:start_idx], data[start_idx:end_idx]
    x.append(data_x)
    y.append(data_y)
  return np.asarray(x), np.asarray(y)

# %%
n_step_in, n_step_out = 60, 7
train_x, train_y = split_data(train.values, n_step_in, n_step_out)
test_x, test_y = split_data(test.values, n_step_in, n_step_out)

# %%
print('train_x.shape : ',train_x.shape)
print('train_y.shape : ',train_y.shape)
print('test_x.shape : ',test_x.shape)
#print('test_y.shape : ',test_y.shape)
# Out:
# train_x.shape :  (1102, 60)
# train_y.shape :  (1102, 7)
# test_x.shape :  (226, 60)

# %%
n_feature = 1
DL_train_x = train_x.reshape((train_x.shape[0],train_x.shape[1],n_feature))
DL_train_y = train_y

DL_test_x = test_x.reshape((test_x.shape[0],test_x.shape[1],n_feature))

# %%
print('DL_train_x.shape : ',DL_train_x.shape)
print('DL_train_y.shape : ',DL_train_y.shape)
print('DL_test_x.shape : ',DL_test_x.shape)
#print('DL_test_y.shape : ',DL_test_y.shape)
# Out:
# DL_train_x.shape :  (1102, 60, 1)
# DL_train_y.shape :  (1102, 7)
# DL_test_x.shape :  (226, 60, 1)

# %% [markdown]
# ### 모델링

# %% [markdown]
# #### RNN

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import SimpleRNN, Dropout

from tensorflow.keras.utils import plot_model

# %%
def model_RNN():
  model = Sequential()
  model.add(SimpleRNN(60, activation='relu',input_shape=(n_step_in,n_feature),return_sequences=True))
  model.add(Dropout(0.5))
  model.add(SimpleRNN(60, activation='relu',return_sequences=False))
  model.add(Dropout(0.5))
  model.add(Dense(60))
  model.add(Dense(n_step_out))

  model.compile(optimizer='adam',loss='mae')
  plot_model(model,show_shapes=True)
  plt.show()

  model.summary()

  try :
    history = model.fit(DL_train_x,DL_train_y,epochs=30)
  except : 
    pass

  pred_model = model.predict(DL_test_x)

  return pred_model

# %%
pred_RNN = model_RNN()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 60, 60)            3720
#
#  dropout (Dropout)           (None, 60, 60)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 60)                7260
#
#  dropout_1 (Dropout)         (None, 60)                0
#
#  dense (Dense)               (None, 60)                3660
#
#  dense_1 (Dense)             (None, 7)                 427
#
# =================================================================
# Total params: 15,067
# Trainable params: 15,067
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 35/35 [==============================] - 4s 28ms/step - loss: 2.9832
# Epoch 2/30
# 35/35 [==============================] - 1s 31ms/step - loss: 2.0590
# Epoch 3/30
# 35/35 [==============================] - 1s 27ms/step - loss: 1.8451
# Epoch 4/30
# 35/35 [==============================] - 1s 39ms/step - loss: 1.7368
# Epoch 5/30
# 35/35 [==============================] - 2s 48ms/step - loss: 1.7503
# Epoch 6/30
# 35/35 [==============================] - 2s 46ms/step - loss: 1.7153
# Epoch 7/30
# 35/35 [==============================] - 1s 32ms/step - loss: 1.7030
# Epoch 8/30
# 35/35 [==============================] - 1s 29ms/step - loss: 1.6808
# Epoch 9/30
# 35/35 [==============================] - 1s 28ms/step - loss: 1.6568
# Epoch 10/30
# 35/35 [==============================] - 1s 28ms/step - loss: 1.6667
# Epoch 11/30
# 35/35 [==============================] - 1s 28ms/step - loss: 1.6165
# Epoch 12/30
# 35/35 [==============================] - 1s 27ms/step - loss: 1.6072
# Epoch 13/30
# 35/35 [==============================] - 1s 28ms/step - loss: 1.6138
# Epoch 14/30
# 35/35 [==============================] - 1s 27ms/step - loss: 1.5497
# Epoch 15/30
# 35/35 [==============================] - 1s 29ms/step - loss: 1.5849
# Epoch 16/30
# 35/35 [==============================] - 2s 69ms/step - loss: 1.5682
# Epoch 17/30
# 35/35 [==============================] - 3s 90ms/step - loss: 1.5792
# Epoch 18/30
# 35/35 [==============================] - 2s 66ms/step - loss: 1.5850
# Epoch 19/30
# 35/35 [==============================] - 2s 62ms/step - loss: 1.5366
# Epoch 20/30
# 35/35 [==============================] - 2s 63ms/step - loss: 1.5777
# Epoch 21/30
# 35/35 [==============================] - 2s 49ms/step - loss: 1.5728
# Epoch 22/30
# 35/35 [==============================] - 1s 28ms/step - loss: 1.5694
# Epoch 23/30
# 35/35 [==============================] - 1s 28ms/step - loss: 1.5469
# Epoch 24/30
# 35/35 [==============================] - 1s 42ms/step - loss: 1.4805
# Epoch 25/30
# 35/35 [==============================] - 2s 55ms/step - loss: 1.4993
# Epoch 26/30
# 35/35 [==============================] - 2s 52ms/step - loss: 1.5520
# Epoch 27/30
# 35/35 [==============================] - 2s 53ms/step - loss: 1.5532
# Epoch 28/30
# 35/35 [==============================] - 2s 55ms/step - loss: 1.5462
# Epoch 29/30
# 35/35 [==============================] - 1s 32ms/step - loss: 1.4980
# Epoch 30/30
# 35/35 [==============================] - 1s 28ms/step - loss: 1.4816
# 8/8 [==============================] - 0s 8ms/step

# %%
print('pred_RNN.shape : ',pred_RNN.shape)
plt.plot(pred_RNN)
# Out:
# pred_RNN.shape :  (226, 7)
# [<matplotlib.lines.Line2D at 0x7fd159b7f160>,
#  <matplotlib.lines.Line2D at 0x7fd159b7f190>,
#  <matplotlib.lines.Line2D at 0x7fd159b7f2b0>,
#  <matplotlib.lines.Line2D at 0x7fd159b7f3d0>,
#  <matplotlib.lines.Line2D at 0x7fd159b7f4f0>,
#  <matplotlib.lines.Line2D at 0x7fd159b7f610>,
#  <matplotlib.lines.Line2D at 0x7fd159b7f730>]
# WARNING:matplotlib.font_manager:findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
plt.plot(pred_RNN[: , -1])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test_y[:, -1], pred_RNN[: , -1])
# Out:
# 2.071083451431409

# %% [markdown]
# #### LSTM

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import LSTM, Dropout

from tensorflow.keras.utils import plot_model

# %%
def model_LSTM():
  model = Sequential()
  model.add(LSTM(60, activation='relu',input_shape=(n_step_in,n_feature),return_sequences=True))
  model.add(Dropout(0.5))
  model.add(LSTM(60, activation='relu',return_sequences=False))
  model.add(Dropout(0.5))
  model.add(Dense(60))
  model.add(Dense(n_step_out))

  model.compile(optimizer='adam',loss='mae')
  plot_model(model,show_shapes=True)
  plt.show()

  model.summary()

  try :
    history = model.fit(DL_train_x,DL_train_y,epochs=30)
  except : 
    pass

  pred_model = model.predict(DL_test_x)

  return pred_model

# %%
pred_LSTM = model_LSTM()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 60)            14880
#
#  dropout_2 (Dropout)         (None, 60, 60)            0
#
#  lstm_1 (LSTM)               (None, 60)                29040
#
#  dropout_3 (Dropout)         (None, 60)                0
#
#  dense_2 (Dense)             (None, 60)                3660
#
#  dense_3 (Dense)             (None, 7)                 427
#
# =================================================================
# Total params: 48,007
# Trainable params: 48,007
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 35/35 [==============================] - 5s 59ms/step - loss: 3.2473
# Epoch 2/30
# 35/35 [==============================] - 4s 101ms/step - loss: 1.9330
# Epoch 3/30
# 35/35 [==============================] - 2s 68ms/step - loss: 1.8262
# Epoch 4/30
# 35/35 [==============================] - 2s 59ms/step - loss: 1.7334
# Epoch 5/30
# 35/35 [==============================] - 2s 60ms/step - loss: 1.6732
# Epoch 6/30
# 35/35 [==============================] - 2s 60ms/step - loss: 1.6657
# Epoch 7/30
# 35/35 [==============================] - 2s 59ms/step - loss: 1.6378
# Epoch 8/30
# 35/35 [==============================] - 4s 103ms/step - loss: 1.5978
# Epoch 9/30
# 35/35 [==============================] - 2s 65ms/step - loss: 1.6150
# Epoch 10/30
# 35/35 [==============================] - 2s 60ms/step - loss: 2159065.5000
# Epoch 11/30
# 35/35 [==============================] - 2s 58ms/step - loss: 14.1229
# Epoch 12/30
# 35/35 [==============================] - 2s 60ms/step - loss: 12.4312
# Epoch 13/30
# 35/35 [==============================] - 2s 60ms/step - loss: 3.6777
# Epoch 14/30
# 35/35 [==============================] - 3s 98ms/step - loss: 3.2667
# Epoch 15/30
# 35/35 [==============================] - 2s 67ms/step - loss: 2.9361
# Epoch 16/30
# 35/35 [==============================] - 2s 60ms/step - loss: 2.6549
# Epoch 17/30
# 35/35 [==============================] - 2s 60ms/step - loss: 2.4895
# Epoch 18/30
# 35/35 [==============================] - 2s 60ms/step - loss: 2.3954
# Epoch 19/30
# 35/35 [==============================] - 2s 60ms/step - loss: 2.2787
# Epoch 20/30
# 35/35 [==============================] - 3s 99ms/step - loss: 2.2317
# Epoch 21/30
# 35/35 [==============================] - 3s 70ms/step - loss: 2.2160
# Epoch 22/30
# 35/35 [==============================] - 2s 60ms/step - loss: 2.1978
# Epoch 23/30
# 35/35 [==============================] - 2s 62ms/step - loss: 2.1180
# Epoch 24/30
# 35/35 [==============================] - 2s 61ms/step - loss: 2.1467
# Epoch 25/30
# 35/35 [==============================] - 2s 63ms/step - loss: 2.1183
# Epoch 26/30
# 35/35 [==============================] - 3s 97ms/step - loss: 2.1025
# Epoch 27/30
# 35/35 [==============================] - 2s 67ms/step - loss: 2.0821
# Epoch 28/30
# 35/35 [==============================] - 2s 61ms/step - loss: 2.0499
# Epoch 29/30
# 35/35 [==============================] - 2s 59ms/step - loss: 2.0558
# Epoch 30/30
# 35/35 [==============================] - 2s 61ms/step - loss: 2.0417
# 8/8 [==============================] - 0s 17ms/step

# %%
print('pred_LSTM.shape : ',pred_LSTM.shape)
plt.plot(pred_LSTM)
# Out:
# pred_LSTM.shape :  (226, 7)
# [<matplotlib.lines.Line2D at 0x7fd0edf1ba90>,
#  <matplotlib.lines.Line2D at 0x7fd0edf1baf0>,
#  <matplotlib.lines.Line2D at 0x7fd0edf1bc10>,
#  <matplotlib.lines.Line2D at 0x7fd0edf1bd30>,
#  <matplotlib.lines.Line2D at 0x7fd0edf1be50>,
#  <matplotlib.lines.Line2D at 0x7fd0edf1bf70>,
#  <matplotlib.lines.Line2D at 0x7fd0edf2a0d0>]

# %%
plt.plot(pred_LSTM[: , -1])

# %%
plt.plot(test_y[:, -1])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test_y[:, -1], pred_LSTM[: , -1])
# Out:
# 2.823262462025195

# %% [markdown]
# #### GRU
# + https://wikidocs.net/22889

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import GRU, Dropout

# %%
def model_GRU():
  model = Sequential()
  model.add(GRU(60, activation='relu',input_shape=(n_step_in,n_feature),return_sequences=True))
  model.add(Dropout(0.5))
  model.add(GRU(60, activation='relu',return_sequences=False))
  model.add(Dropout(0.5))
  model.add(Dense(60))
  model.add(Dense(n_step_out))

  model.compile(optimizer='adam',loss='mae')
  plot_model(model,show_shapes=True)
  plt.show()

  model.summary()

  try :
    history = model.fit(DL_train_x,DL_train_y,epochs=30)
  except : 
    pass

  pred_model = model.predict(DL_test_x)

  return pred_model

# %%
pred_GRU = model_GRU()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 60, 60)            11340
#
#  dropout_5 (Dropout)         (None, 60, 60)            0
#
#  gru_1 (GRU)                 (None, 60)                21960
#
#  dropout_6 (Dropout)         (None, 60)                0
#
#  dense_8 (Dense)             (None, 60)                3660
#
#  dense_9 (Dense)             (None, 7)                 427
#
# =================================================================
# Total params: 37,387
# Trainable params: 37,387
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 35/35 [==============================] - 6s 67ms/step - loss: 3.4692
# Epoch 2/30
# 35/35 [==============================] - 3s 93ms/step - loss: 1.7976
# Epoch 3/30
# 35/35 [==============================] - 3s 90ms/step - loss: 1.7399
# Epoch 4/30
# 35/35 [==============================] - 2s 67ms/step - loss: 1.6698
# Epoch 5/30
# 35/35 [==============================] - 2s 66ms/step - loss: 1.5790
# Epoch 6/30
# 35/35 [==============================] - 2s 65ms/step - loss: 1.6037
# Epoch 7/30
# 35/35 [==============================] - 3s 73ms/step - loss: 1.5808
# Epoch 8/30
# 35/35 [==============================] - 4s 106ms/step - loss: 1.5659
# Epoch 9/30
# 35/35 [==============================] - 2s 66ms/step - loss: 1.5215
# Epoch 10/30
# 35/35 [==============================] - 2s 65ms/step - loss: 1.5011
# Epoch 11/30
# 35/35 [==============================] - 2s 67ms/step - loss: 1.5148
# Epoch 12/30
# 35/35 [==============================] - 2s 66ms/step - loss: 1.5280
# Epoch 13/30
# 35/35 [==============================] - 3s 97ms/step - loss: 1.5103
# Epoch 14/30
# 35/35 [==============================] - 3s 83ms/step - loss: 1.4703
# Epoch 15/30
# 35/35 [==============================] - 3s 86ms/step - loss: 1.5194
# Epoch 16/30
# 35/35 [==============================] - 2s 69ms/step - loss: 1.4861
# Epoch 17/30
# 35/35 [==============================] - 2s 66ms/step - loss: 1.4655
# Epoch 18/30
# 35/35 [==============================] - 3s 97ms/step - loss: 1.5031
# Epoch 19/30
# 35/35 [==============================] - 3s 89ms/step - loss: 1.4819
# Epoch 20/30
# 35/35 [==============================] - 2s 69ms/step - loss: 1.4528
# Epoch 21/30
# 35/35 [==============================] - 2s 66ms/step - loss: 1.4760
# Epoch 22/30
# 35/35 [==============================] - 2s 67ms/step - loss: 1.4712
# Epoch 23/30
# 35/35 [==============================] - 3s 80ms/step - loss: 1.4568
# Epoch 24/30
# 35/35 [==============================] - 4s 103ms/step - loss: 1.4185
# Epoch 25/30
# 35/35 [==============================] - 2s 66ms/step - loss: 1.4463
# Epoch 26/30
# 35/35 [==============================] - 2s 67ms/step - loss: 1.4529
# Epoch 27/30
# 35/35 [==============================] - 2s 67ms/step - loss: 1.4376
# Epoch 28/30
# 35/35 [==============================] - 2s 65ms/step - loss: 1.4293
# Epoch 29/30
# 35/35 [==============================] - 4s 110ms/step - loss: 1.4310
# Epoch 30/30
#  1/35 [..............................] - ETA: 3s - loss: 1.2534

# %%
print('pred_GRU.shape : ', pred_GRU.shape)
plt.plot(pred_GRU)
# Out:
# pred_GRU.shape :  (226, 7)
# [<matplotlib.lines.Line2D at 0x7fd0eef51670>,
#  <matplotlib.lines.Line2D at 0x7fd0eef516d0>,
#  <matplotlib.lines.Line2D at 0x7fd0eef517f0>,
#  <matplotlib.lines.Line2D at 0x7fd0eef51910>,
#  <matplotlib.lines.Line2D at 0x7fd0eef45550>,
#  <matplotlib.lines.Line2D at 0x7fd0eef45580>,
#  <matplotlib.lines.Line2D at 0x7fd0eef51b50>]

# %%
plt.plot(pred_GRU[: , -1])

# %%
plt.plot(test_y[:, -1])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test_y[:, -1], pred_GRU[: , -1])
# Out:
# 1.9571272110559241

# %% [markdown]
# #### CNN

# %%
from keras.layers import Flatten
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D

# %%
def model_CNN():
  model = Sequential()
  model.add(Conv1D(input_shape=(n_step_in,n_feature),filters=64, kernel_size=2,activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Conv1D(filters=64, kernel_size=2,activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Flatten())
  model.add(Dense(60, activation='relu'))
  model.add(Dense(n_step_out))

  model.compile(optimizer='adam',loss='mae')
  plot_model(model,show_shapes=True)
  plt.show()

  model.summary()

  try :
    history = model.fit(DL_train_x,DL_train_y,epochs=30)
  except : 
    pass

  pred_model = model.predict(DL_test_x)

  return pred_model

# %%
pred_CNN = model_CNN()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 59, 64)            192
#
#  max_pooling1d (MaxPooling1D  (None, 29, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 28, 64)            8256
#
#  max_pooling1d_1 (MaxPooling  (None, 14, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 896)               0
#
#  dense_4 (Dense)             (None, 60)                53820
#
#  dense_5 (Dense)             (None, 7)                 427
#
# =================================================================
# Total params: 62,695
# Trainable params: 62,695
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 35/35 [==============================] - 1s 7ms/step - loss: 2.5711
# Epoch 2/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.5819
# Epoch 3/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.3646
# Epoch 4/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.3128
# Epoch 5/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.3028
# Epoch 6/30
# 35/35 [==============================] - 0s 10ms/step - loss: 1.2713
# Epoch 7/30
# 35/35 [==============================] - 0s 12ms/step - loss: 1.2530
# Epoch 8/30
# 35/35 [==============================] - 0s 11ms/step - loss: 1.2696
# Epoch 9/30
# 35/35 [==============================] - 0s 12ms/step - loss: 1.2407
# Epoch 10/30
# 35/35 [==============================] - 0s 11ms/step - loss: 1.2268
# Epoch 11/30
# 35/35 [==============================] - 0s 11ms/step - loss: 1.2152
# Epoch 12/30
# 35/35 [==============================] - 0s 11ms/step - loss: 1.2353
# Epoch 13/30
# 35/35 [==============================] - 0s 12ms/step - loss: 1.2111
# Epoch 14/30
# 35/35 [==============================] - 0s 11ms/step - loss: 1.2099
# Epoch 15/30
# 35/35 [==============================] - 0s 12ms/step - loss: 1.2084
# Epoch 16/30
# 35/35 [==============================] - 0s 11ms/step - loss: 1.1895
# Epoch 17/30
# 35/35 [==============================] - 0s 8ms/step - loss: 1.1949
# Epoch 18/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.2150
# Epoch 19/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1964
# Epoch 20/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1759
# Epoch 21/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1855
# Epoch 22/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1767
# Epoch 23/30
# 35/35 [==============================] - 0s 6ms/step - loss: 1.1738
# Epoch 24/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1733
# Epoch 25/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1564
# Epoch 26/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1615
# Epoch 27/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1447
# Epoch 28/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1473
# Epoch 29/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1548
# Epoch 30/30
# 35/35 [==============================] - 0s 7ms/step - loss: 1.1533
# 8/8 [==============================] - 0s 3ms/step

# %%
print('pred_CNN.shape : ',pred_CNN.shape)
plt.plot(pred_CNN)
# Out:
# pred_CNN.shape :  (226, 7)
# [<matplotlib.lines.Line2D at 0x7fd0edb7fa60>,
#  <matplotlib.lines.Line2D at 0x7fd0edb7fac0>,
#  <matplotlib.lines.Line2D at 0x7fd0edb7fbe0>,
#  <matplotlib.lines.Line2D at 0x7fd0edb7fd00>,
#  <matplotlib.lines.Line2D at 0x7fd0edb7fe20>,
#  <matplotlib.lines.Line2D at 0x7fd0edb7ff40>,
#  <matplotlib.lines.Line2D at 0x7fd0edb8e0a0>]

# %%
plt.plot(pred_CNN[:,-1])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test_y[:, -1], pred_CNN[: , -1])
# Out:
# 2.024197191120249

# %% [markdown]
# #### CNN-LSTM

# %%
from keras.layers import RepeatVector #펼친 벡터를 LSTM에 각각의 입력으로 넣음, 플랫된 값이 n_step_out의 수만큼 만복해서 들어감
from keras.layers import TimeDistributed #LSTM의 리턴값으로 받은 스퀀스 각각에 대해 수행

# %%
def model_CNN_LSTM():
  model=Sequential()
  model.add(Conv1D(input_shape=(n_step_in,n_feature),filters=64, kernel_size=2,activation='relu'))
  model.add(MaxPooling1D(pool_size=2))
  model.add(Flatten())
  model.add(RepeatVector(n_step_out))

  model.add(LSTM(120, activation='relu',return_sequences=True))
  model.add(Dropout(0.5))
  model.add(TimeDistributed(Dense(60,activation='relu')))
  model.add(TimeDistributed(Dense(n_step_out)))

  model.compile(optimizer='adam',loss='mae')
  plot_model(model,show_shapes=True)
  plt.show()

  model.summary()

  try :
    history = model.fit(DL_train_x,DL_train_y,epochs=30)
  except : 
    pass

  pred_model = model.predict(DL_test_x)

  return pred_model

# %%
pred_CNN_LSTM = model_CNN_LSTM()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 59, 64)            192
#
#  max_pooling1d_2 (MaxPooling  (None, 29, 64)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1856)              0
#
#  repeat_vector (RepeatVector  (None, 7, 1856)          0
#  )
#
#  lstm_2 (LSTM)               (None, 7, 120)            948960
#
#  dropout_4 (Dropout)         (None, 7, 120)            0
#
#  time_distributed (TimeDistr  (None, 7, 60)            7260
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 7, 7)             427
#  tributed)
#
# =================================================================
# Total params: 956,839
# Trainable params: 956,839
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 8/8 [==============================] - 0s 18ms/step

# %%
print('pred_CNN_LSTM.shape : ',pred_CNN_LSTM.shape)
plt.plot(pred_CNN_LSTM[:, -1])
# Out:
# pred_CNN_LSTM.shape :  (226, 7, 7)
# [<matplotlib.lines.Line2D at 0x7fd1595524c0>,
#  <matplotlib.lines.Line2D at 0x7fd159552b20>,
#  <matplotlib.lines.Line2D at 0x7fd159552ca0>,
#  <matplotlib.lines.Line2D at 0x7fd159700fd0>,
#  <matplotlib.lines.Line2D at 0x7fd1597004c0>,
#  <matplotlib.lines.Line2D at 0x7fd159700cd0>,
#  <matplotlib.lines.Line2D at 0x7fd159700880>]

# %%
plt.plot(pred_CNN_LSTM[:, -1][:,-1])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(test_y[:, -1], pred_CNN_LSTM[: , -1][:,-1])
# Out:
# 9.817830698477483

# %% [markdown]
# ### 모델 피팅
